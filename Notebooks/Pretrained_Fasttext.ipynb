# %% [markdown]
# ### Download german spacy pipeline

# %%
# !python -m spacy download de_core_news_lg
# Out:
# Collecting de-core-news-lg==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_lg-3.3.0/de_core_news_lg-3.3.0-py3-none-any.whl (567.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 567.8/567.8 MB 22.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from de-core-news-lg==3.3.0) (3.3.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (1.8.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (0.9.1)
# Requirement already satisfied: packaging>=20.0 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (21.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (3.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (1.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (1.22.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (2.0.7)
# Requirement already satisfied: setuptools in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (58.0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (3.0.9)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (1.0.7)
# Requirement already satisfied: jinja2 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (3.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (2.4.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (4.63.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (8.0.15)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (0.7.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (2.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (0.6.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (3.0.8)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (4.2.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (2022.6.15)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (8.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->de-core-news-lg==3.3.0) (2.1.1)
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_lg')

# %%
# !pip install fasttext
# Out:
# Requirement already satisfied: fasttext in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (0.9.2)
# Requirement already satisfied: numpy in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from fasttext) (1.22.4)
# Requirement already satisfied: setuptools>=0.7.0 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from fasttext) (58.0.4)
# Requirement already satisfied: pybind11>=2.2 in /Users/jannis/opt/miniconda3/lib/python3.9/site-packages (from fasttext) (2.9.2)
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
import spacy
import re
import umap
nlp = spacy.load('de_core_news_lg')

# %%
data = pd.read_csv("data/prepared_dataframe.csv")

# %%
# split data in training and test
data_train = data.sample(round(0.75 * len(data)), random_state = 1).reset_index()
data_test = data[~data.index.isin(data_train.index)].reset_index()

# %%
data_pre = data_train

# %%
# create spacy docs with a nlp pipeline
# https://spacy.io/usage/processing-pipelines
tweet_docs = [nlp(tweet) for tweet in data_pre["tweets_clean"]]

# %%
# extract the generated lemmas for words that are no stopwords and have a length of more than two
# Lemmatization is the process of reducing inflected forms of a word while still ensuring that the reduced
# form belongs to the language. This reduced form or root word is called a lemma.
tweet_words = [
    [
    word.lemma_ for word in doc if ((not word.is_stop) and (len(word) >= 3))
    ]
    for doc in tweet_docs]

# %%
tweet_words
# Out:
# [['läppisch',
#   'Euro',
#   'Afd',
#   'Welt',
#   'Demokratieuntergang',
#   'herbei',
#   'schreiben',
#   '....',
#   'süß'],
#  ['finden', 'eklig', 'Body', 'Shamer', 'Schäm'],
#  ['Umwelt',
#   'Scheiße',
#   'Mann',
#   'hören',
#   'grün',
#   'Sumpf',
#   'schwachköpfe',
#   'steuergeldern',
#   'finanzieren',
#   'kosten',
#   'Arbeitsplatz',
#   'Stadt',
#   'sterben',
#   'Unsinn',
#   'nahrung',
#   'aussprechen'],
#  ['gehören', 'mal', '26,5', 'Stunde'],
#  ['Abschiebung',
#   'kriminell',
#   'Migrant',
#   'Heimat',
#   'eventuell',
#   'Gefahr',
#   'drohen',
#   'setzen',
#   'Bevölkerung',
#   'Gefahr',
#   'Opfer',
#   'Verbrechen',
#   'bevor',
#   'ausländisch',
#   'Straftäter',
#   'abschieben',
#   'linker',
#   'gutmenschen-terror'],
#  ['~faktor',
#   'mensch~',
#   'Banane',
#   'Geländewag',
#   '300',
#   'funktionieren',
#   'Kommunismus',
#   'werft',
#   'eur',
#   'marx-werke',
#   'Müll',
#   'Freunde'],
#  ['Sozialschmarotzer', 'vorher', 'fragen'],
#  ['Diskussionsveranstaltung',
#   '\\""die',
#   'Fehler',
#   'gsp-denkens',
#   'verkehrt',
#   'Kritik',
#   'Peter',
#   'checker',
#   'Wien',
#   '29.01.19',
#   '19:00',
#   'Hörsaal',
#   'Universitätsstr'],
#  ['kennn', 'Glaub', 'gibts', 'cash', 'Sau'],
#  ['zerstören', 'dein', 'Begriffsapparat', 'zerstören', 'Feind'],
#  ['isses', 'sogar', 'Katze', 'sitzen', 'gebannt', 'Fernseher', '--'],
#  ['verstehen', 'eur', 'Witz', 'meinen', 'ernst'],
#  ['Nacht',
#   'schicksalhaft',
#   'Nacht',
#   'Nacht',
#   'voll',
#   'leid',
#   'wut',
#   'Schmerzen',
#   'Träne',
#   'Dutzend',
#   'Mensch',
#   'quälen',
#   'erbarmungslos',
#   'gnadenlos',
#   'skrupellos',
#   'Schicksalsnacht',
#   'beginnen',
#   'leis',
#   'unbedacht',
#   'Boah'],
#  ['bedenken',
#   'unermesslich',
#   'leid',
#   'Menschheit',
#   'kommen',
#   'un-emmissionsziel',
#   'tatsächlich',
#   'einhalten',
#   'bedenken',
#   '19.jhdt',
#   'emmitiert',
#   'Treibhausgase',
#   'Anteil',
#   'Atmosphäre',
#   'ausmachen',
#   'Größenordnung',
#   '--'],
#  ['kriegsbegeistert', 'antideutsch', 'Hohlkörper'],
#  ['Trauerzug',
#   'Afd',
#   'Geschändet',
#   'ermordet',
#   'jüdisch',
#   'Mädchen',
#   'SPD',
#   'rufen',
#   'Nazis',
#   'raus',
#   'Chemnitz',
#   'Merkel',
#   'Mietmaul',
#   'erfinden',
#   'Hetzjagd',
#   'künftig',
#   'Konzert',
#   'links',
#   'Sozi',
#   'raus',
#   'rufen',
#   'Darwin',
#   'Award',
#   'jeder',
#   'rotgrün',
#   'Opfer',
#   'Toleranz',
#   'Offenheit',
#   'naiv',
#   'Tilgung',
#   'Genpool'],
#  ['unglaublich',
#   'deutsch',
#   'Presse',
#   'regen',
#   'rechtsnational',
#   'Ministerpräsident',
#   'Viktor',
#   'Orbán',
#   'nähmlich',
#   'SPD',
#   'grün',
#   'Hartz',
#   'System',
#   'Ungarn',
#   'Einführen.sie',
#   'regen',
#   'SPD',
#   'grüne',
#   'Deutschland',
#   'haben.toll'],
#  ['potentiell', 'Messerstecher', 'abschieben', 'müssten', 'wirsindmehropf'],
#  ['verlieren', 'follower', 'homöopathisch', 'Dos', 'entfolgen'],
#  ['Karte', 'Zeithorizont', 'posten', '--'],
#  ['1945',
#   'Fall',
#   'verhindern',
#   'international',
#   'schaffen',
#   'Palästinafrage',
#   'Lakmustest',
#   'System',
#   'funktionieren',
#   'wichtig',
#   'gerecht',
#   'lösen'],
#  ['sagen',
#   'Sabber',
#   'Fliesst',
#   'warten',
#   'Seehofer',
#   'Amt',
#   'verlässen',
#   'ausgetrocknet',
#   'Pflaume'],
#  ['Nazi',
#   'Gestapo',
#   'Gott',
#   'empören',
#   'Frau',
#   'Maischberger',
#   'fragen',
#   'helfen'],
#  ['Spruch', 'zeigen', 'wes', 'Geist', 'Kind'],
#  ['islamistisch',
#   'anschlag',
#   'gleich',
#   'Atemzug',
#   'geflüchtet',
#   'migrant_inn',
#   'hetzen',
#   'Asylrecht',
#   'infrage',
#   'stellen',
#   'Ahnung',
#   'Mechanism',
#   'Islamismus',
#   'wissen',
#   'Wirkung',
#   'Radikalisierung',
#   'komplex'],
#  ['Geschichte',
#   'anderer',
#   '--',
#   'Europäer',
#   'ankommen',
#   'sowohl',
#   'Antisemitismus',
#   'zionismus',
#   'Levante',
#   'bringen'],
#  ['überspitzen',
#   'grade',
#   'Situation',
#   'rechtlich',
#   'Verfolgung',
#   'Selbstjustiz',
#   'Opposition',
#   'rechtfertigen',
#   'beschuldigst',
#   'schwer',
#   'Straftat',
#   'sicher',
#   'beweisen'],
#  ['Bürgi',
#   'Journos',
#   'Hehe',
#   'verschwörungstheorien',
#   'verblenden',
#   'stecken',
#   'bestimmen',
#   'Putin'],
#  ['Afd',
#   'Ferkelfunk',
#   'abschaffen',
#   'linker',
#   'Zeck',
#   'schmarotz',
#   'Angst',
#   'kacken',
#   'arbeiten',
#   'Führer',
#   'treu',
#   'senden',
#   'Dreck',
#   'lügen',
#   '--'],
#  ['hahahaha',
#   '.....',
#   'Maas',
#   'SPD',
#   'don',
#   'Quijote',
#   'groß',
#   'Witz',
#   'Politikgeschicht',
#   'eingehen'],
#  ['wissen',
#   'woher',
#   'Fax',
#   '....',
#   'gewiß',
#   'Sekt',
#   'gefällen',
#   'Opferrolle',
#   'Mehrheit',
#   'stellen',
#   'Taqiyya',
#   'Hinterkopf',
#   'halten',
#   'fax',
#   'schnell',
#   'verschicken',
#   'klar',
#   'Ferkelfunk',
#   'erweisen',
#   'ansehen',
#   '--'],
#  ['kriegen',
#   'mails',
#   'verschieden',
#   'Variation',
#   'Woche',
#   'Itler',
#   'wissen',
#   'Ignore',
#   'schalten'],
#  ['orientalisch',
#   'Jude',
#   'z.b.',
#   'Händler',
#   'Tross',
#   'Römer',
#   'ziehen',
#   'ca.',
#   '1500',
#   'sicher',
#   'Nachfahr',
#   'Stammbaum',
#   '....',
#   'lassen',
#   'testen'],
#  ['Humanrightsday',
#   'Menschenrecht',
#   'Deutschland',
#   'Million',
#   'Mensch',
#   'SPD',
#   'CDU',
#   'CSU',
#   'grün',
#   'FDP',
#   'Agenda',
#   '2010',
#   'Harz',
#   'Einführung',
#   'Hartz',
#   'arbeitssklav',
#   'Damt',
#   'reich',
#   'Profit'],
#  ['Gabalier',
#   'valentin-orden',
#   'bekommen',
#   'konservativ',
#   'neudeutsch',
#   'rechts',
#   'laut',
#   'Frau',
#   'Rinberger',
#   'valentin-museum',
#   '\\""frauenfeindlich\\',
#   'sagen',
#   'Million',
#   'weiblich',
#   'Fan'],
#  ['bitte', 'wissen', 'genau', 'jung', 'männlich', 'Migrant', 'aufschlagen'],
#  ['Anti',
#   'deutsch',
#   'Kämpfer',
#   'verschwörungstheorien',
#   'lügenpresse',
#   'exakt',
#   'Argument',
#   'russisch',
#   'Verschwörung',
#   'russisch',
#   'lügenpresse'],
#  ['naja', 'Bochum', 'unabsteigbar\\"immer', 'überwinden'],
#  ['hartz-reformen',
#   'hart',
#   'notwendig',
#   'Blick',
#   'Frankreich',
#   'zeigen',
#   'vergleichsweise',
#   'hoch',
#   'sozialhilfeleistung',
#   'lässt',
#   'Heer',
#   'arbeitslose',
#   'Dauer',
#   'ruhigstellen',
#   'Leute',
#   'arbeiten'],
#  ['Siri',
#   'spielen',
#   'egb',
#   'Antigerman',
#   'Audioporn',
#   'zeign',
#   'Definition',
#   'ironisch',
#   'Überspitzung'],
#  ['unrecht'],
#  ['fragen',
#   'verquirlt',
#   'Welt',
#   'leben',
#   'ernsthaft',
#   'stehen',
#   'nix',
#   'präsentieren',
#   'männer\\"da',
#   'stehen',
#   'Präsentieren.und',
#   'Frau',
#   'sagen',
#   'hey',
#   'pack',
#   'Dinger',
#   'belästigung.\\""verstehst',
#   'belästigen',
#   'Hölle',
#   'Incel'],
#  ['Nachfahr', 'levantinisch', 'Händler', 'Jahrhundert', 'Europäer', '--'],
#  ['gshen',
#   'ertragsstärker',
#   'anlageformen',
#   'gemeinsam',
#   'Verfügbarkeit',
#   'gebunden',
#   'Finanz',
#   'Sofort\\"ist'],
#  ['Brauchst',
#   'Hilfe',
#   'politisch',
#   'Gegner',
#   'lassn',
#   'einfach',
#   'reden',
#   'Stegner'],
#  ['lernen'],
#  ['Niedersachsen',
#   'Ministerpräsident',
#   'fordern',
#   'Neuwahl',
#   'Neuwahl',
#   'Dercdu',
#   'Angst',
#   'Stuhl',
#   'kleben',
#   'bleiben'],
#  ['mittlerweile',
#   'tun',
#   'irgendwie',
#   'leid',
#   'mal',
#   'cool',
#   'irgendwann',
#   'mal',
#   'geistig',
#   'falsch',
#   'abbogen',
#   'korrigieren',
#   'beschleunigen',
#   'aktiv',
#   'smh'],
#  ['Heimat',
#   'verlieren',
#   'Minderheit',
#   'Land',
#   'Björn',
#   'höcken',
#   'Afd',
#   'Staatsfeind',
#   'beobachten',
#   'Verfassungsschutz',
#   'politisch',
#   'verfolgen',
#   'Kartell',
#   'Union',
#   'SPD',
#   'grün',
#   'FDP',
#   'linker',
#   'meinen',
#   'Menschenwürde',
#   'gehören',
#   'Heimat'],
#  ['interessieren',
#   'korrupt',
#   'berufslügn',
#   '-verleumder',
#   'Völkerrecht',
#   'Mietmäuler',
#   'kotzen',
#   'bergeweise',
#   'lügen',
#   'Hass',
#   'Netz',
#   'paar',
#   'ahnungslos',
#   'trottel',
#   'hängenbleiben',
#   '--',
#   'womit',
#   'sogar'],
#  ['denken',
#   'Banker',
#   'Fall',
#   'Mann',
#   'Vorraum',
#   'zusammenbrechen',
#   'sterben',
#   'Kunde',
#   'angewidert',
#   'rüber',
#   'steigen',
#   'helfen'],
#  ['feststellen',
#   'offenbar',
#   'groß',
#   'Erfahrung',
#   'Aktie',
#   'schwerfallen',
#   'Aktie',
#   'schlecht',
#   'Performance',
#   'erreichen',
#   'alternative',
#   'genau',
#   'Mentalitätsproblem',
#   'hinaus'],
#  ['anchmal', 'kotzen', 'Dogmatismus', 'linker'],
#  ['retweeen', 'antisemin', '---&gt', 'Primosantoro'],
#  ['Schäuble', 'Vdleyen', 'Schwarzgeld', 'geben', 'Erblindung', 'führen', '--'],
#  ['einfach', 'Ferse', 'heften'],
#  ['lel', 'Karte', 'Auge'],
#  ['saudämlich', 'Tore', '--', 'Spiel', 'verlieren', 'Fcsp'],
#  ['cool', 'Film', 'Konter', 'Paul', 'Newman'],
#  ['sonderbar',
#   'twitter-soziolekt',
#   'mittlerweile',
#   'ziemlich',
#   'toll',
#   'finden',
#   'ziemlich',
#   'unsicher'],
#  ['Landeplatz', 'Pleitegeier'],
#  ['jedesmal',
#   'lachflash',
#   'gesellschaft\\"sich',
#   'irgendein',
#   'Problem',
#   'verständigen',
#   'Kapitalist',
#   'jucken'],
#  ['tja',
#   'mal',
#   'gespannt',
#   'grüne',
#   'hart',
#   'vorgehen',
#   'Polizei',
#   'kritisieren',
#   'Geiselnahme',
#   'Dankepolizei',
#   'Arbeit',
#   'Refugeesnotwelcome'],
#  ['blöd',
#   'politisch',
#   'Ideologie',
#   'Religion',
#   'unterscheiden',
#   'wissen',
#   'genügen',
#   '--'],
#  ['mal', 'lügen', 'kommi-bubble', 'kennen'],
#  ['Herr',
#   'Walde',
#   'hören',
#   'heucheln',
#   'alleine',
#   'Auftritt',
#   'Störer',
#   'einstudiert',
#   'Frage',
#   'Bestellung',
#   'komplett',
#   'entlarven',
#   'dringlich',
#   'Thema',
#   'komplett',
#   'außen',
#   'Lemming',
#   'klatschen',
#   'pfui',
#   'Deibel',
#   'schlimm',
#   'enden'],
#  ['Verzweiflung',
#   'Altpartei',
#   'Verfassungsschutz',
#   'Leine',
#   'lassen',
#   'Afd',
#   'deutsch',
#   'Nationalstaat',
#   'erhalten',
#   'eigentlich',
#   'Verfassungsschutz',
#   'Inquisition',
#   'Maischberger'],
#  ['verstehen',
#   'Bevölkerung',
#   'diskutieren',
#   'wählen',
#   '1001',
#   'deligieren',
#   'Umfrage',
#   'Kölner',
#   'Innenstadt',
#   'komplett',
#   'maybritilln'],
#  ['laufen',
#   'zeigen',
#   'Nippel',
#   'Brüst',
#   'wackeln',
#   'Takt',
#   'wunderschön',
#   'Anblick',
#   'Belästigung',
#   'möchten',
#   'Mann',
#   'eng',
#   'Hos',
#   'sehen',
#   'Ader',
#   'Sack',
#   'zählen',
#   'mal'],
#  ['allererster', 'Punkt', 'mindestens', '100', 'Wert'],
#  ['bitte', 'ertragen'],
#  ['überaus',
#   'interessant',
#   'innerhalb',
#   'Tag',
#   'Kahrs',
#   'erfahren',
#   'fett',
#   'Akt',
#   'Klüngelei',
#   'bedrohungen',
#   'Beleidigung',
#   'minderjährig',
#   'Bube',
#   'übernachten',
#   'alk',
#   'gibts',
#   'Früchtch'],
#  ['ehemalig',
#   'Sprecher',
#   'Israeli',
#   'Terror',
#   'forces',
#   'Kriegsverbrecher',
#   'Kriegsverbrechen',
#   'Terrororganisation',
#   'angehören',
#   'klein',
#   'reden',
#   'beschönigen',
#   'Frage',
#   'hoffentlich',
#   'international',
#   'Strafgerichtshof',
#   'beschäftigen',
#   '....'],
#  ['schießen',
#   'Bein',
#   'Frage',
#   'Ausweichst',
#   'explizit',
#   'Studie',
#   'fragen',
#   'biologisch',
#   'Grundfaktore',
#   'berücksichtigen',
#   'Antwort',
#   'Studie',
#   'Biologie',
#   'respektieren',
#   'nötig',
#   'ist\\'],
#  ['eher',
#   'Tat',
#   'interessiert',
#   'Sprüch',
#   'gucken',
#   'Kandidat',
#   'klar',
#   'konservativ',
#   'gucken',
#   'Historie',
#   'deutlich',
#   'mitmachen'],
#  ['Challenge',
#   'Music',
#   'November',
#   'befreien',
#   'kleinbürgerlich',
#   'Ideologie'],
#  ['Stegner',
#   'letzter',
#   'sagen',
#   'Stegner',
#   'absolut',
#   'Proll',
#   'Idiot',
#   'bestes',
#   'Afd',
#   'Werbepferd'],
#  ['Stimmungsbarometer',
#   'amazon-spamversuch-sackgesicht',
#   'Beef',
#   'beginnen',
#   'Wort',
#   'fuck',
#   '--',
#   'Asshole!\\'],
#  ['Byzantiner',
#   'Palästina',
#   'übernehmen',
#   'zwingen',
#   'einheimisch',
#   'Konversion',
#   'Christentum',
#   'treten',
#   'meister',
#   'Islam',
#   'meister',
#   'Nachfahr',
#   'antik',
#   'Hebräer',
#   'muslimisch',
#   'Palästinenser',
#   '--'],
#  ['Ahnung', 'denken', 'unterschiede'],
#  ['SPD',
#   'Vorstand',
#   'seeheim',
#   'Kreis',
#   'triffen',
#   'gestern',
#   'reden',
#   'entscheiden',
#   'toll',
#   'entscheiden',
#   'SPD',
#   'erneuern',
#   'Partei',
#   'Lösung'],
#  ['genau',
#   'Palästina',
#   'errichtet',
#   'zionistisch',
#   'Kolonie',
#   'namens',
#   'Israel'],
#  ['Schuh', 'schieben', 'Grenze', 'schließen'],
#  ['Lösung', 'gewinnen', '--', 'Fcsp'],
#  ['Ohje',
#   'Polygamie',
#   'Anfänger',
#   'Tatort',
#   '--',
#   'Amateur',
#   '-*kopfschüttel'],
#  ['tja', '--', 'bescheuert', 'Relegation', 'ebswob', 'fckdfb'],
#  ['ideologisch',
#   'Vordenker',
#   'Kolonisierung',
#   'schreiben',
#   'Jewish',
#   'Colonial',
#   'Trust',
#   'finanzieren',
#   'u.a.',
#   'Palestine',
#   'Jewish',
#   'Colonization',
#   'Association',
#   'durchführen',
#   'lassen',
#   'worum',
#   'handeln'],
#  ['exakt', 'bekommen'],
#  ['scheinst', 'Leistungsprinziep', 'voll', 'aufzugehen', '--'],
#  ['dürfen',
#   'Zenit',
#   'überschreiten',
#   'sehen',
#   'Scharia',
#   'Frau',
#   'Wahlrecht',
#   'besitzen',
#   '100jahrefrauenwahlrecht'],
#  ['glauben', 'langsam', '--', 'fcsp'],
#  ['klar', 'Ungunst', 'Afd', 'einzelfall', 'experen'],
#  ['lauf', 'bio-company', 'Streu', 'Glyphosat', 'äpfel'],
#  ['schade',
#   'solch',
#   'mies',
#   'dreckig',
#   'Abschaum',
#   'Menschheit',
#   'Weg',
#   'laufen'],
#  ['Thüringen',
#   '43-jährig',
#   'Obergeschoss',
#   'Haus',
#   'fallen',
#   'besserem',
#   'Empfang',
#   'Handy',
#   'suchen',
#   'Glück',
#   'Unglück',
#   'unten',
#   'ankommen',
#   'Mobilfunknetz',
#   'finden',
#   'Deutschland',
#   'Internet',
#   'danke',
#   'SPD',
#   'CDU',
#   'CSU'],
#  ['11h',
#   'Frankfurt',
#   'Kaisersack',
#   'Eskalation',
#   'groß',
#   'Atommächt',
#   'Syrien',
#   'Kundgebung',
#   'Anschl',
#   'Demo',
#   'Innenstadt',
#   'Abschlusskundgebung',
#   'Paulsplatz',
#   'frieden',
#   'zukunftswerkstatt',
#   'u.a.'],
#  ['Umweltheinis',
#   'heiß',
#   'Hintern',
#   'Wüstenstad',
#   'Umwelt',
#   'messen',
#   'scwachköpfe',
#   'Welt',
#   'retten'],
#  ['eigentlich',
#   'kapitalistisch',
#   'Gesellschaft',
#   'übel',
#   'menschenverachtend',
#   'Sekten',
#   'anrichten',
#   'per',
#   'Gesetz',
#   'abstellen'],
#  ['Birmingham',
#   'England',
#   'Ausmass',
#   'schlimm',
#   'Täter',
#   'Opfer',
#   'Empörung',
#   'Ferkelfunk',
#   'falsch',
#   'Täter',
#   'Klientel',
#   'gering',
#   '--'],
#  ['Abtreibung',
#   'Geburt',
#   'SPD',
#   'Nachwuchs',
#   'basteln',
#   'Projekt',
#   '4,8',
#   'verschwinden',
#   'versenkung\\'],
#  ['Nürnberg',
#   'Angst',
#   'unbekannt',
#   'messer-attacken',
#   'Flucht',
#   'toll',
#   'söd',
#   'CSU',
#   'Bayern',
#   'sicher',
#   'Bundesland',
#   'Deutschland',
#   'hören',
#   'Opfer',
#   'verhöhnen'],
#  ['Asexuelleraltmaier2.0',
#   'realitätsfern',
#   'Marionett',
#   'Geld',
#   'verpulvern',
#   'wählen',
#   'pampers-',
#   'hosenscheisser',
#   'sofort',
#   'Wahlrecht',
#   'entziehen',
#   'Absurdistan',
#   'Mann'],
#  ['spielen', 'satirisch', 'doppelrolle'],
#  ['pass', 'nehmen', 'Leute', 'ernst'],
#  ['dcleaks',
#   'Beweis',
#   'Hillary',
#   'Clinton',
#   'betreiben',
#   'kinderporno-ring',
#   'solltest',
#   'eher',
#   'Gesprächspartner',
#   'Synelly',
#   'suchen'],
#  ['uff', '--', 'Sobiech', 'Eigentor\\"kackt', 'afm-stream', 'Fcsp'],
#  ['unterschiedlich',
#   'Hautfarb',
#   'unterschiedlich',
#   'Kontinent',
#   'zumindest',
#   'Erinnerung'],
#  ['schicken'],
#  ['mio',
#   'islamisch',
#   'christen-und',
#   'Judenhassern',
#   'Europa',
#   'importieren',
#   'sorry',
#   '--',
#   'Papst',
#   'weiß',
#   'robe',
#   'verhüllt',
#   'Manager',
#   'multi-milliard',
#   'Konzern',
#   'bekanntlich',
#   'lutschen',
#   'Manager',
#   'gerne',
#   'Knaben',
#   'rum',
#   'Pfaff'],
#  ['Jude',
#   'religiös',
#   'Vertretung',
#   'Staat',
#   'finanzieren',
#   'Religion',
#   'gelten',
#   '--'],
#  ['T-34', 'Reparatur'],
#  ['nix',
#   'esseb',
#   'Kühlschrank',
#   'sein',
#   'weg',
#   'weggegammelt',
#   'Erganhg',
#   'bitt'],
#  ['differenzieren',
#   'stellen',
#   'klar',
#   'Hauptfeind',
#   'linker',
#   'Rechtsoffen',
#   'Struktur',
#   'Verwicklung',
#   'Nazi',
#   'Szene',
#   'sorry'],
#  ['lesen',
#   'einfach',
#   'erwähnt',
#   'Buch',
#   'renommiert',
#   'israelisch',
#   'Historiker',
#   'Archivmaterial',
#   'Aussage',
#   'Zeitzeug',
#   'möglich',
#   'Quelle',
#   'verarbeiten',
#   'sprechen'],
#  ['dummerchen',
#   'hätt',
#   'selber',
#   'drauf',
#   'obwohl',
#   'wofür',
#   'brauchen',
#   'Passagierliste'],
#  ['Ferkel',
#   'schloss',
#   'pkw',
#   'Maut',
#   'Mörder',
#   'Verbrecher',
#   'Invasion',
#   'Land',
#   'Wort',
#   'Wert',
#   '--'],
#  ['kennen', 'umhören', 'zufrieden', 'politisch', 'ändern', 'riskant'],
#  ['verwirrt',
#   'weigern',
#   'Tatsache',
#   'anerkennen',
#   'Hass',
#   'Ferkel',
#   'importieren',
#   '....',
#   'bezwecken',
#   'selber',
#   'belügen',
#   'unverständlich'],
#  [],
#  ['stimmen', '....', 'arm', 'Kind', 'sicher', 'Islam'],
#  ['tun',
#   'dreist',
#   'Lügner',
#   'weisen',
#   'Zionismus',
#   'jüdisch',
#   'Emanzipationsbewegung',
#   'schwächen',
#   'positiv',
#   'Entwicklung',
#   'Osteuropa',
#   'absichtlich',
#   'verhindern',
#   'Herzls',
#   'Argument',
#   'revolutionär',
#   'jüdisch',
#   'Massen\\"in',
#   'Kolonie',
#   'ableiten'],
#  ['btw', 'eigentlich', 'Robert', 'Mugabe'],
#  ['naja',
#   'Nazikommunist',
#   'vergessen',
#   'Argument',
#   'schimpfworten',
#   'schmeissen'],
#  ['Scheiße',
#   '16jährige',
#   'multipl',
#   'psychisch',
#   'Erkrankung',
#   'Bär',
#   'Ring',
#   'Nase',
#   'Manege',
#   'führen',
#   'runterholen',
#   'Dummheit',
#   'bestätigen',
#   'total',
#   'bescheuert'],
#  ['schlimm',
#   'Gefahr',
#   'Fortexistenz',
#   'Abendlande',
#   'momentan',
#   'Jugendwiderstand',
#   'Glück',
#   "gibt'sn",
#   'Tapfer',
#   'Aufklärer',
#   'ausm',
#   'Demokratie',
#   'linksextrem',
#   'vandalen',
#   'verteidigen'],
#  ['raffen', 'yotta', 'Evelyn', 'dumm', 'Ibes'],
#  ['Lügner', 'Mutti', '....', ';-)'],
#  ['König', 'Ludwig', 'romantischere', 'Schlösser', 'bauen'],
#  ['führen',
#   'Plan',
#   'Vorgänger',
#   'völkerbund',
#   'einfach',
#   '--',
#   'stehen',
#   'verlinkt',
#   'Mandatstext'],
#  ['denken', 'geil', 'Song', '8bit-mix'],
#  ['Europäer',
#   'Tourist',
#   'irgendwann',
#   'Vertreibung',
#   'schnell',
#   'Kommandeur',
#   'halten',
#   'Plan',
#   'jüdisch',
#   'Nachbar',
#   'schützen',
#   'Million',
#   'einheimisch',
#   'bleiben',
#   'übrig'],
#  ['Wort',
#   'Menschenverstand',
#   'fallen',
#   'entsichern',
#   'Hegelianer',
#   'Bombe',
#   'sehen',
#   'Masse',
#   'Bombensicher',
#   'unterstandr',
#   'um.\\"(gl',
#   '215'],
#  ['Gott',
#   'rall',
#   'Bordesholm',
#   'shisha-pfeifen',
#   'jauch',
#   'füllen',
#   'e-auto',
#   'energiewend',
#   'Laien',
#   'Abschätzung',
#   'Folge',
#   'rein',
#   'opportunistisch',
#   'Aktionismus',
#   "geht's",
#   'Hose'],
#  ['Land',
#   'Daniel',
#   'Pascal',
#   'Zorn',
#   'Philosoph',
#   'gelten',
#   'brauchen',
#   'philosophie-bekämpfung'],
#  ['SPD',
#   'Energiewende',
#   'Stromkunden',
#   'entlasten',
#   'Stromrechnung',
#   'niht',
#   'bezahlen',
#   'Zukunft',
#   'preiswert',
#   'Kerze',
#   'kaufen',
#   'können.toll',
#   'Tafel',
#   'Kerze',
#   'verteilen'],
#  ['protokolliern',
#   'Wartezeit',
#   'Februar',
#   'neu',
#   'Job',
#   'insgesamt',
#   '11:27',
#   'Warterei',
#   'verbringen',
#   'Oktober',
#   'erfreulich',
#   'positiv',
#   'Öpnv',
#   'einfach',
#   'schlimm'],
#  ['Ntv', 'aufklären'],
#  ['Steinbruch',
#   'Gummihammer',
#   'Granitblock',
#   'setzen',
#   'befehlen',
#   'machn',
#   'Sand',
#   'Draus!\\',
#   'zack',
#   'Ruhe'],
#  ['eigentlich',
#   'Zentralrat',
#   'Jude',
#   'Merkel',
#   'Glanzstück',
#   'Migrationspakt'],
#  ['egal',
#   'böse',
#   'Knot',
#   'regelmäßig',
#   'Behandlung',
#   'kurz',
#   'Intervalle',
#   'zeitinensiv',
#   'verbinden',
#   'medi-cocktail',
#   'geändert',
#   'Speiseplan',
#   'Not',
#   'Funny'],
#  ['nennen',
#   'Kapitalismus',
#   '--',
#   'ständig',
#   'moralisieren',
#   '....',
#   'nehmen',
#   'Realität',
#   'willens',
#   'änder'],
#  ['Lieblingsrestaurant',
#   'fantastisch',
#   'salatbar',
#   'großartig',
#   'french',
#   'dressing',
#   'hab',
#   'Handel',
#   'finden',
#   'u+202f',
#   'Billigmarke',
#   'Metro'],
#  ['Kapuzendeppe',
#   'rocken',
#   'hart',
#   'ansonsten',
#   'Tarantino',
#   'Tiefgründe',
#   'Analyse',
#   'Sklaverei',
#   'darfste',
#   'halt',
#   'einfach',
#   'erwarten'],
#  ['Ermittler', 'zählen'],
#  ['kinder-ehen',
#   'akzeptieren',
#   'verbieten',
#   'wackeln',
#   'Verfassungsgericht',
#   'bestimmen',
#   'zulassen.bei',
#   'Flüchtling'],
#  ['Linksfaschist', 'geblocken'],
#  ['Nazi', 'besiegen', 'Rest', 'unschuldig', 'deutsch'],
#  ['Militär', 'Mann', 'Frau'],
#  ['sehen',
#   'bislang',
#   'Unrechtsbewusstsein',
#   'unrecht',
#   'Leute',
#   'missverständlich',
#   'Liste',
#   'setzen'],
#  ['nice', 'Arbeit', 'Fall'],
#  ['sowieso', 'bürgerlich', 'Restvernunft'],
#  ['echt', 'blöd', 'Typ', 'kriegen', 'gerade', 'Satz', 'heraus'],
#  ['denken', 'sofort', 'Dschungelcamp'],
#  ['erkennen',
#   'mal',
#   'Überweisungsträger',
#   'per',
#   'Hand',
#   'ausfüllen',
#   'wissen',
#   'Umfeld'],
#  ['danken',
#   'dein',
#   'Kampfgeist',
#   'Kratzbürstigkeit',
#   'wunderbar',
#   'Frau',
#   'Bild'],
#  ['blöd', '--', 'gerne', 'gewinnen', 'Fcsp'],
#  ['erwarten',
#   'Leute',
#   'komplett',
#   'blau',
#   'anmalt',
#   'Finger',
#   'absägt',
#   'Witz',
#   'Hand',
#   'sagen',
#   'bloß',
#   'Shego',
#   'echt',
#   'Energiebändigerin',
#   'Umprofesionehl'],
#  ['folgen',
#   'Gott',
#   'Teufel',
#   'Bild',
#   'Auge',
#   'Tweet',
#   'Schulter',
#   'hocken',
#   'plärren',
#   'interessant',
#   'Gedanke',
#   'interessant',
#   'Gemeinschaft',
#   'freuen',
#   'brennen',
#   '@gottesgetweet'],
#  ['Aussage',
#   'entnehmen',
#   'ungeboren',
#   'Person',
#   'vorhanden',
#   'sobald',
#   'Herz',
#   'schlagen',
#   'sein',
#   'zumindest',
#   '37,3',
#   'abbrüche',
#   'Meinung',
#   'okay',
#   'nebenbei',
#   'bemerken',
#   'wüssten',
#   'denken',
#   'alt',
#   'Erde',
#   'wegmit219a',
#   'Wegmit218'],
#  ['--', 'situativ', 'räume', 'überlädt', '--', '\\"alter', 'sky', 'Fcsp'],
#  ['13h',
#   'russ.konsulat',
#   'Frankfurt',
#   'Kundgebung',
#   'Krieg',
#   'Türkei',
#   'Afrin',
#   'Russ',
#   'Hilfe',
#   'eschersheim',
#   'Anlage',
#   'Defendafrin'],
#  ['nahles',
#   'Hartz',
#   'abschaffen',
#   'System',
#   'Namen.die',
#   'Bürger',
#   'auffordern',
#   'Name',
#   'finden',
#   'SPD',
#   'Parteivorstand',
#   'Schicken.dann',
#   'mal'],
#  ['--',
#   'Angriffskrieg',
#   'Nachbar',
#   'kommen',
#   'Palästinenser',
#   'Hilfe',
#   'mörderisch',
#   'zionistisch',
#   'Siedlerterrorist',
#   'Heimat',
#   'vertreiben',
#   'hundert',
#   'massakriern'],
#  ['Ampel', 'grün', 'arm', 'Socke'],
#  ['unpopulär',
#   'vertrag',
#   'nunmal',
#   'intransparent',
#   'weitgehend',
#   'Ausschluss',
#   'Öffentlichkeit',
#   'aushandeln',
#   'sehen',
#   'ttip',
#   'migrations-',
#   'Flüchtlingspakt',
#   'aachen',
#   'Vertrag',
#   'usw.',
#   'Merkel',
#   'verhassen',
#   'Macron',
#   'Drap',
#   'Rouge',
#   'Franzose',
#   'lautlos'],
#  ['cem',
#   'özdemir',
#   'grüne',
#   'Rede',
#   'Jahr',
#   '2018',
#   'auszeichnen',
#   'bekommen',
#   'golden',
#   'vollpfo'],
#  ['200er', 'Gegenrichtung', 'Station', 'Endhaltestelle', '--', 'lächerlich'],
#  ['Arte', 'laufen', 'Rammstein', 'Paris'],
#  ['arabischsprachig',
#   'Medium',
#   'geben',
#   'letzter',
#   'Nacht',
#   'vollständig',
#   'infos'],
#  ['solange',
#   'Staat',
#   'billig',
#   'Anbieter',
#   'nehmen',
#   'Fördern\\"bei',
#   'Hartz',
#   'sowieso',
#   '--',
#   'annewill'],
#  ['heißen',
#   'Liebkind',
#   'Lyzi',
#   'Lily',
#   'Suri',
#   'Seli',
#   'Daniel',
#   'Proletarier',
#   'Tagesspiegel',
#   'voice'],
#  ['schreiben',
#   'fühlen',
#   'denken',
#   'sperren',
#   '......',
#   'sofort',
#   'aufhören',
#   '....'],
#  ['Jesus',
#   'literarisch',
#   'Figur',
#   'Sagen',
#   'legend',
#   'Region',
#   'zusammengefasst',
#   'real',
#   'Person',
#   'sein',
#   'Nachfahr',
#   'wahrscheinlich',
#   'muslimisch',
#   'Palästinenser'],
#  ['Meldemuschis', 'schaden', 'Follower', 'brauch', 'rein'],
#  ['gemeinsam',
#   'Zuganreise',
#   'kurzentschlossene',
#   'ffm',
#   '10:15h',
#   'Gleis',
#   'hbf',
#   'nsu',
#   'Halit',
#   'Keinnächstesopfer',
#   'Temmeinderklemme'],
#  ['machen', 'dein', 'Job'],
#  ['machen', 'sowas'],
#  ['schön', 'erkennen', 'tweets', 'selber', 'schreiben', 'zusammenpastest'],
#  ['mal', 'weiterhin', 'schön', 'gammelfleisch', 'Döner', 'kaufen'],
#  ['laß', 'überraschen', 'Verlauf', 'geschildert', 'Kollegin', 'berichten'],
#  ['Student',
#   'Mensch',
#   'Ticket',
#   'rausholen',
#   'bevor',
#   'Kontrolleur',
#   'stehen'],
#  ['Mal', 'gefühlt', 'Saison', 'mal', 'Tipp', 'stimmen', '--', 'Fcsp'],
#  ['Prokrastination',
#   '\\""betroffene',
#   'leiden',
#   'meist',
#   'dauerhaft',
#   'berichten',
#   'teilweise',
#   'schulzeit',
#   'Problem',
#   'erleben',
#   'spät',
#   'beruf',
#   'ableistisch',
#   'schaden',
#   'Volkskörper',
#   '--',
#   'kotzen'],
#  ['weiß', 'sofort', 'Seite', 'gelbwest', 'sehen', 'aufbringen'],
#  ['zerstören',
#   'effektiv',
#   'Zukunft',
#   'Land',
#   'mal',
#   'überlegen',
#   'zerstören',
#   'einzig',
#   'Rohstoff',
#   'Land',
#   'Intelligenz',
#   'Innovation',
#   'Erfindungsreichtum',
#   '--',
#   'sagen',
#   'Ferkel',
#   'sagen',
#   'Ziel',
#   'vollkommen',
#   'erreichen',
#   '--'],
#  ['ernsthaft',
#   'stolz',
#   'posten',
#   'naja',
#   'dummer',
#   'glauben',
#   'freu',
#   'eur',
#   'ohrfeig',
#   'Bayern',
#   'Wahl',
#   'klatsch',
#   'klatsch',
#   'mia',
#   'San'],
#  ['wahrscheinlich',
#   'Wegwolle',
#   "sich's",
#   'all',
#   'inklusive',
#   'Hängematte',
#   'mal',
#   'gemütlich',
#   'Ernüchterung',
#   'Verärgerung',
#   'erfahrungsgemäß',
#   'fehlend',
#   'schokopudding',
#   'Handynetz',
#   'ausrasten',
#   '--'],
#  ['genau',
#   'selber',
#   'denken',
#   'Meinung',
#   'darstellen',
#   'interessieren',
#   'widerlich',
#   'Rassist',
#   'Name',
#   'Diffamierung',
#   'herhalten',
#   'verkappt',
#   'Herrenmensch',
#   '....'],
#  ['tun',
#   'Frege',
#   'Russell',
#   'quine',
#   'Usw',
#   'durchlaufen',
#   'Derrida',
#   'Zusammenhang',
#   'Philosophie',
#   'Geld'],
#  ['deutsch',
#   'jüdisch',
#   'bolschewistisch',
#   'weltverschwörung~',
#   'antideutsch',
#   'intellektuell',
#   'islamisch',
#   'stalinistisch',
#   'despotie~'],
#  ['linker', 'Feind', 'reden', 'halt', 'Schmutz', 'verstaubt', 'Rhetorik'],
#  ['Land',
#   'Einwanderung',
#   'Hand',
#   'international',
#   'Schlepperbande',
#   'legen',
#   'diskutieren',
#   'Bürger',
#   'Tempolimit',
#   'einführen',
#   'Mosaik',
#   'Wahnsinn',
#   'vervollständigen',
#   'Stückchen',
#   'Menschenverstand'],
#  ['geben',
#   'Lieblingsaccounts',
#   'Suchlupe',
#   'finden',
#   'schnell',
#   'wissen',
#   'wieviele',
#   'abgespeicheren'],
#  ['find', 'austeilen', 'einstecken'],
#  ['eigentum',
#   'verpflichten',
#   'maximale',
#   'heraus',
#   'holen',
#   'Politik',
#   'tanzen',
#   'passend',
#   'singen',
#   'Lied',
#   'mieterverarschungsbrems',
#   'glotzen',
#   'wichtig',
#   'Ferkelfunk',
#   'Kamera',
#   '--'],
#  ['überwachen', 'eigentlich', 'Verfassungsschutz', 'Kanzleramt'],
#  ['nativ',
#   'American',
#   'Opfer',
#   'siedlerkolonial',
#   'Regime',
#   'langsam',
#   'fragen',
#   'Zeitung',
#   'vorliesen',
#   'erklären',
#   '--'],
#  ['Afd', 'Rechtsaußen', 'stehen'],
#  ['Wetter', 'Gephotoshopped', '--', 'fcsp', 'Millerntor'],
#  ['Geschwister',
#   'Leute',
#   'Tür',
#   'ficken',
#   'heuchelnd',
#   'festtags-alkoholiker'],
#  ['jedenfalls'],
#  ['tagelang',
#   'Tsunami',
#   'Indonesien',
#   'intensivst',
#   'berichten',
#   'scheinen',
#   'wichtigees',
#   'geben',
#   'stark',
#   'Schneefall',
#   'Alpenregion',
#   'jeder',
#   'Natur',
#   'Wetterphänom',
#   'Weltuntergang',
#   'aufbauen'],
#  ['sparen', 'Abwehr', 'werfen', 'vorne', '--', 'Fcsp'],
#  ['Europa',
#   'Kleinstaaterei',
#   'Player',
#   'USA',
#   'Russland',
#   'China',
#   'zerreiben',
#   'lassen',
#   '....'],
#  ['Spitze',
#   'eisberges',
#   'Glaubwürdigkeit',
#   'längst',
#   'verlieren',
#   'finden',
#   'bemerkenswert',
#   'eindeutig',
#   'positionieren',
#   'Stadt',
#   'CDU',
#   'Politiker',
#   'cojones',
#   'geben'],
#  ['Durchschnittsdeutsch',
#   'laufen',
#   'Merkelismus',
#   'grün',
#   'Spinnerei',
#   'hinterher',
#   'nazisraus-tugendstolzen',
#   'inbrünstig',
#   'heil',
#   'hitler\\"gebrüllt',
#   'Systemherde',
#   'stets',
#   'opportunistisch'],
#  ['Ball', 'Birne', 'kriegen'],
#  ['Haltung', 'belohnen', 'Follower'],
#  ['definieren',
#   'klar',
#   '\\""feminist\\',
#   'blocken',
#   'Blase',
#   'wachsen',
#   'rosa',
#   'häschenohren'],
#  ['soviel',
#   'erinnern',
#   'mittlerweile',
#   'blocken',
#   'einzig',
#   'Twitterkreis',
#   'twitter-gifs'],
#  ['faktenfind', 'schreiben'],
#  ['Kaffee',
#   'Pfoste',
#   'gelb',
#   'Westen',
#   'Pfoste',
#   'allesamt',
#   'egal',
#   'Grundschullehrer',
#   'gerecht',
#   'Entlohnung',
#   'protestieren',
#   'Nazi',
#   'einfach',
#   'Hobbyautoanzünder'],
#  ['Börse',
#   'Aktie',
#   'zockerei!\\',
#   'schimpfen',
#   'deutsch',
#   'kaufen',
#   'wöchentlich',
#   'Lottoschein'],
#  ['Keks', 'abgeschoben', 'Moslem', 'Jawollo', 'Frau', 'Merkel'],
#  ['neu',
#   'Feigst',
#   'Propagandafuzzi',
#   'zionistisch',
#   'Völkermörderkolonie',
#   'geraubt',
#   'ethnisch',
#   'gesäubert',
#   'Heimatland',
#   'Palästinenser',
#   'Wahrheit',
#   'taugen',
#   'mal',
#   'Toilettenpapier',
#   'flauschig',
#   '--'],
#  ['arabisch',
#   'Quelle',
#   'melden',
#   'flüchtig',
#   'Täter',
#   'polizeibekannt',
#   'aufgrund',
#   'Terroraktivitäte',
#   'dran'],
#  ['sogenannter',
#   'Aktivist',
#   'Hambacherforst',
#   'richtig',
#   'Verkacker',
#   'einfach',
#   'Hause',
#   'spielen',
#   'eur',
#   'Garten',
#   'nerven',
#   'Polizei',
#   'hambibleiben'],
#  ['lesen',
#   'Tweet',
#   'mal',
#   'gewählt',
#   'Form',
#   'hilfsverbs',
#   'stehen',
#   'Konjunktiv'],
#  ['hinweisen',
#   'Fachbegriff',
#   'Fehlhaltung',
#   'lumbar',
#   'lordosis\\"ist',
#   'beenden',
#   'Beweisführung',
#   'Benennung',
#   'zuständig',
#   'wusste'],
#  ['eigentlich',
#   'Preis',
#   'demokratisch',
#   'gewählt',
#   'Regierung',
#   'stürzen',
#   'terror-regime',
#   'errichten',
#   'billig',
#   'Glaub',
#   'Iraner',
#   '--'],
#  ['übertreiben', 'n', 'bürgerlich', 'Bündnis', 'verbauen', 'üblich'],
#  ['umstritten',
#   'Paragraf',
#   '219a',
#   'SPD',
#   'unterstellen',
#   'Frau',
#   'prekär',
#   'Lebenssituation',
#   'leichtfertigkeit.sonst',
#   'Entscheidung',
#   'laut',
#   'Müssen.allein',
#   'Begriff',
#   'werbeverbot\\"unterstellt',
#   'einerseits',
#   'geldgier',
#   'ärzten',
#   'Leichtfertigkeit',
#   'Frau'],
#  ['Glorreiche\\"beendigung',
#   'Krieg',
#   'kriege',
#   'produzieren',
#   'Verlierer',
#   'bilden',
#   'Grundlage',
#   'künftig',
#   'Konflikt',
#   'Türkei',
#   'Angriff',
#   'scheitern',
#   'Hoffnung'],
#  ['innere\\"feind', 'groß', 'Gefahr'],
#  ['kurz',
#   'Frage',
#   'finden',
#   'Name',
#   'wahr',
#   'Vertreter',
#   'einzig',
#   'wahr',
#   'Pustekuchen',
#   'Gruppe',
#   'innerhalb',
#   'Interessenfelde',
#   'legitimieren',
#   'diskreditieren'],
#  ['empfinden',
#   'tendenziös',
#   'front',
#   'Text',
#   'Intention',
#   'verfolgen',
#   'What'],
#  ['amüsant', 'sinnlos', '--', 'Tatort'],
#  ['Partei', 'brauchen', 'sowas'],
#  ['allmählich', 'gelangen', 'Auffassung', 'zeitraubend', 'Troll'],
#  ['umsetzen', 'bislang', 'nichtmal', 'Land', 'Realität', 'umsetzen'],
#  ['Presseclub',
#   'blubbern',
#   'erneut',
#   'CDU',
#   'verloren',
#   'Wählerstimm',
#   'wahrscheinlich',
#   'interessieren',
#   'Selbstzerstörungsprozess',
#   'Deutschland',
#   'aufhalten'],
#  ['verdammt',
#   'Antifagruppe',
#   'solid',
#   'gsp',
#   'antideutsch',
#   'all',
#   'Trotzkist',
#   'anarchos',
#   'zusllererst',
#   'befassen',
#   'Realsozialismus',
#   'abgrenzen',
#   'vorauseilend',
#   'gehorsam'],
#  ['irgendwann',
#   'mal',
#   'Geld',
#   'verdienen',
#   'wert',
#   'white',
#   'Supremacist',
#   '--'],
#  ['gefühl\\"vorzuwerf',
#   'hart',
#   'Stück',
#   'bitte',
#   'geben',
#   'Quelle',
#   'Definition'],
#  ['schön'],
#  ['Bundespdräsident',
#   'Mann',
#   'sagen',
#   'SPD',
#   "gibt's",
#   'nicht.wir',
#   'mal',
#   'halten'],
#  ['deutlich',
#   'sagen',
#   'echt',
#   'rassisten',
#   'finden',
#   'widerlich',
#   'angeboren',
#   'Phänotyp',
#   'ändern',
#   'verurteilen',
#   'verhalten',
#   'kritisieren',
#   'liegen',
#   'nämlich',
#   'Verantwortung',
#   'Gegensatz',
#   'Rasse'],
#  ['nix',
#   'Mut',
#   'angeblich',
#   'unteilbar',
#   'Liberalismus',
#   'teilen',
#   'z.b.',
#   'königskörp',
#   '1789.',
#   'Name',
#   'Thomas',
#   'Schmitz',
#   'Gruß'],
#  ['einfach',
#   'peinlich',
#   'sogenannter',
#   'Aktivist',
#   'Hambibleibt',
#   'benehmen',
#   'grundlos',
#   'Gekreische',
#   'Nichtsnutz',
#   'aushalten',
#   'danken',
#   'Polizei',
#   'eur',
#   'Einsatz',
#   'Hambacherforst'],
#  ['sofort', 'mal', 'Sprechort', 'reflektieren'],
#  ['romantisch', 'Kommunismus', 'denken', 'mal', 'drüber', 'Freund'],
#  ['Manfred',
#   'Weber',
#   'Plan',
#   'widersprechen',
#   'real',
#   'merkel-politik',
#   '2015.'],
#  ['Scheiße', 'deutsch', '--', 'b0911'],
#  ['Kritiker',
#   'korrupt',
#   'propaganda-mietmäuler',
#   'Hetzer',
#   'letzter',
#   'Funke',
#   'Moral',
#   'Menschlichkeit',
#   'abkaufen',
#   'lassen',
#   'ziemlich',
#   'letzter',
#   'Mensch',
#   '--'],
#  ['Solidaritycityfrankfurt',
#   'rufen',
#   'Kundgebung',
#   'Freitag',
#   '27.',
#   'April',
#   '17:30',
#   'Sozialdezernat',
#   'Schillerstraße',
#   'Frankfurt',
#   'Fried',
#   'Hütte',
#   'Solidarität',
#   'Bewohnerinn',
#   'leerstehend',
#   'Ferro',
#   'Geländes',
#   'Gutleut',
#   'Viertel'],
#  ['arm', 'Kerl', 'sündig', 'Gedanke', 'Hölle', 'brennen'],
#  ['hab',
#   'momentan',
#   'Ahnung',
#   'Protest',
#   'Revolt',
#   'Frankreich',
#   'halten',
#   'entläd',
#   'geballt',
#   'Volkszorn',
#   'hoffen',
#   'Akt',
#   'Regression',
#   'ausarten'],
#  ['früh',
#   'einfach',
#   'Gruppe',
#   'Rehe',
#   'Straße',
#   'wandern',
#   'bistimmen',
#   'Zeitumstellung',
#   'nich',
#   'mitbekommen'],
#  ['lesen',
#   'Fake',
#   '--',
#   'linksfaschistisch',
#   'staatstreu',
#   'Schmierblatt',
#   'Spiegel'],
#  ['Nahle',
#   'verschwinden',
#   'dumm',
#   'akumemte',
#   'klar',
#   'Inhalt',
#   'dumme',
#   'Rede'],
#  ['Haft',
#   'Abdul',
#   'gehören',
#   'sofort',
#   'Prozessende',
#   'freilassen',
#   '3,2,1',
#   'vertrottelt',
#   'Gutmensch',
#   'fordern',
#   'Menschenrecht',
#   'bla',
#   'bla',
#   'Blubb'],
#  ['echt',
#   'Neujahrsvorsätze',
#   '2019',
#   'SPD',
#   'CDU',
#   'CSU',
#   'grün',
#   'FDP',
#   'wählen',
#   'Leben',
#   'gut',
#   'wenden'],
#  ['selten', 'son', 'Dreck', 'Fernsehen', 'sehen', 'Krone18'],
#  ['jung',
#   'schreiben',
#   'antisemitisch',
#   'dreck',
#   'gleichzeitig',
#   'vollverblödet',
#   'Variant',
#   'Kritik',
#   'lappen',
#   'eigentlich'],
#  ['Glas',
#   'Wein',
#   'schlafen',
#   'Tweet',
#   'schlafen',
#   'Reply',
#   'schlafen',
#   'Lied',
#   'schlafen',
#   'Gedanke',
#   'wach',
#   'fuck'],
#  ['Misogyn',
#   'Incel',
#   'armselig',
#   'peinlich',
#   'bla',
#   'bla',
#   'bla',
#   'ziehen',
#   'chat',
#   'Verlauf',
#   'hart',
#   'stören'],
#  ['erwecken',
#   'falsch',
#   'fatal',
#   'Eindruck',
#   'Polizeieinsätze',
#   'können',
#   'politisch',
#   'beeinflussn',
#   'kettenhunde',
#   'Kapital',
#   'absolut',
#   'unpolitisch',
#   '--',
#   'Police',
#   'national',
#   'police',
#   'Capitale'],
#  ['Mann', 'lichtgestalten', 'händeringend', 'suchen', 'derzeit'],
#  ['Jalla',
#   'arabisch',
#   'Klaus',
#   'kennen',
#   'letzter',
#   'bestimmt',
#   'Lederblümchenmandarine'],
#  ['scheinbar',
#   'zuviel',
#   'Crystalmeth',
#   'konsumieren',
#   'bekanntlich',
#   'dumm',
#   'dämlich'],
#  ['öhm',
#   '--',
#   'übersehen',
#   'Volk',
#   'entstehen',
#   'Land',
#   'verlassen',
#   'wechselnd',
#   'Herrschern',
#   'Religion',
#   'wechseln',
#   'nennen',
#   'Palästinenser'],
#  ['eigentlich',
#   'müssen',
#   'sowas',
#   'lachen',
#   'wüssen',
#   'dunkel',
#   'Stunde',
#   'nah',
#   'rücken'],
#  ['zufrieden', '--', 'Fcsp'],
#  ['Protest', 'Landesparteitag', 'Afd', 'Flörsheim', 'stadthall', 'Noafd'],
#  ['denken', 'irgendwann', 'Glück'],
#  ['Kampf',
#   'cdu-merkelmussweg',
#   'Parteispitze',
#   'Merz',
#   '90er',
#   'Spahn',
#   'Klapsmühle',
#   'kramp-#karrenbauer',
#   'Merkel',
#   'Politik',
#   'hatt',
#   'CDU',
#   'bieten'],
#  ['sogenannter',
#   'Aktivist',
#   'Paradies',
#   'Grund',
#   'zurecht',
#   'spinnen',
#   'Polizei',
#   'angreifen',
#   'Lügengeschicht',
#   'verbreiten',
#   'hambibleeben'],
#  ['politisch',
#   'Partei',
#   'stehen',
#   'Ausschluss',
#   'Afd',
#   'Überschrift',
#   'dreimal',
#   'erwähnen',
#   '....'],
#  ['Stimmung', 'Länderspiel', 'Diemannschaft', '--', 'Fckdlf', 'Fcksky'],
#  ['Geschmack', 'trinken', 'ausgekocht', 'Wasser', ';-)'],
#  ['Idee', 'Marktwirtschaft', 'zulässen'],
#  ['Woke',
#   'Sinn',
#   'Wokebubble',
#   'sorry',
#   'deutsch',
#   'linker',
#   'feiern',
#   'amilinke',
#   'Antiamerikanismus',
#   'frönen'],
#  ['anscheinend',
#   'Jude',
#   'Deutschland',
#   'ungemütlich',
#   'Glaube',
#   'öffentlich',
#   'erkennen',
#   'geben',
#   'bedrohen',
#   'jüdisch',
#   'Leben',
#   'Deutschland'],
#  ["seh's",
#   'differenziert',
#   'Randalierer',
#   'Plünderer',
#   'Brandstifter',
#   'Polizei',
#   'Härt',
#   'vorgehen',
#   'friedlich',
#   'weitermachen'],
#  ['likes',
#   'Schwachsinn',
#   'Nonazi',
#   'fckafd',
#   'Feminismus',
#   'white',
#   'Guilt',
#   'Anarchie',
#   'gesinnungsbolschewiki',
#   'Fraktion'],
#  ['grauenhaft',
#   'Merkel',
#   'furchtbar',
#   'potentiell',
#   'Nachfolger',
#   'schlimm',
#   '--'],
#  ['Scheiß',
#   'Politik',
#   'SPD',
#   'CDU',
#   'CSU',
#   '100',
#   'Million',
#   'Arbeitstag',
#   'ausfallen',
#   'Depression',
#   'anderer',
#   'psychisch',
#   'leiden',
#   'Politik',
#   'Merkel–',
#   'doppelt'],
#  ['wuseldst', 'schonwied', 'rum'],
#  ["sag's",
#   'ruhig',
#   'habn',
#   'asozial',
#   'Pisser',
#   'aufgrund',
#   'fehlend',
#   'Argument',
#   'wild',
#   'beleidigen'],
#  ['einzig', 'plausibel', 'zulässig', 'Antwort', 'Twitter'],
#  ['tweet',
#   "you're",
#   'such',
#   'big',
#   'fan',
#   'Dietmar',
#   'dath',
#   'Name',
#   '--',
#   'essential',
#   'content',
#   'his',
#   'books\\"und',
#   'Drunterkommentiere'],
#  ['uni',
#   'Bochum',
#   'sammeln',
#   'Islamist',
#   'spenden',
#   'vorgebl',
#   'geflüchtet',
#   'falls',
#   'ffm',
#   'cent',
#   'syr',
#   'Brüder'],
#  ['alt',
#   'Bulletin',
#   'Board',
#   'Regel',
#   'auspacken',
#   'Hitler',
#   'Verloren\\',
#   '--',
#   'gähn',
#   'Krieg',
#   'selten',
#   'Wahl',
#   '--'],
#  ['linker',
#   'Extremismus',
#   'Absicht',
#   'rot',
#   'Terror',
#   'leugnen',
#   'verharmlost'],
#  ['einst',
#   'Bückling',
#   'famos',
#   'schmecken',
#   'Nacht',
#   'Wälzen',
#   'Hitzewallunge',
#   'auslösen',
#   'mögen',
#   'ergehen'],
#  ['unendlich',
#   'froh',
#   'Bundesregierung',
#   'aids-test',
#   'Mensch',
#   'fordern',
#   'illegal',
#   'Zutritt',
#   'verschaffen',
#   'Afrika',
#   'Aids',
#   'verbreiten',
#   'Weltaidstag'],
#  ['Block',
#   'nebst',
#   'straßenschlägern',
#   'stehen',
#   'Afd',
#   'Relikt',
#   'kohl-cdu',
#   'politisch',
#   'verfolgen',
#   'einsam',
#   'entgegen',
#   'traurig',
#   'Zeit',
#   'Massenzuwanderung',
#   'Islamisierung',
#   'Dieselenteignung',
#   'energiekosten',
#   'Nullzins',
#   'Altersarmut',
#   'ausufernd',
#   'Niedriglohn',
#   'Volk',
#   'drangsalieren'],
#  ['Wahrheit',
#   'an',
#   'Licht',
#   'müssen',
#   'google-suchmaschine',
#   'sperren',
#   'Wahrheit',
#   'unterdrücken',
#   'googeln'],
#  ['peinlich', 'Rechtschreibfeeler'],
#  ['Zeichen', 'Revolution', 'Mittagessen', 'Fanta', 'Fanta', 'unbesiegbar'],
#  ['genau',
#   'pietätlos\\"daran',
#   'sagen',
#   'u.u',
#   'sogar',
#   'Familie',
#   'ideologisch',
#   'Grund',
#   'Bürgerkriegsgebiet',
#   'ziehen',
#   'verdrängen',
#   'Folge',
#   'zuzuschreiben'],
#  ['Erdkundebuch', 'Gymnasium', '80er', 'stehen', 'Satz', 'Hunger', 'dumm'],
#  ['Woche',
#   '1652zig',
#   'Einlieferung',
#   'Befund',
#   'Krebs',
#   'Darm',
#   'blasen',
#   'notwendig',
#   'Operation',
#   'künstlerisch',
#   'Darmausgang',
#   'Prognose',
#   'Monat',
#   'eher',
#   'höchstens',
#   'Ostern',
#   '2019',
#   'wahrscheinlich',
#   'erleben',
#   'Familie',
#   'schocken',
#   'verzweifelt',
#   'traurig',
#   'Panik'],
#  ['mindestens',
#   'maxirent',
#   '--',
#   'Topf',
#   'Cent',
#   'Beitrag',
#   'Steuer',
#   'Unterstützung',
#   'Privatversicherung',
#   '--',
#   'drüber',
#   'Maxi',
#   'bekommen',
#   'laufen',
#   'mindest',
#   '1500',
#   'Bedingung',
#   'spätestens'],
#  ['nehmen', 'Realität', 'mal', 'Kenntnis', 'überwiegend', 'jung', 'Mann'],
#  ['bedrohen',
#   'linke',
#   'Tod',
#   'Mmn',
#   'Tagesspiegel',
#   'Phänomen',
#   'extra',
#   'losgelöst',
#   'Szene',
#   'betrachten',
#   'rechtsoffen',
#   'Struktur',
#   'gering',
#   'Solidarität',
#   'geben'],
#  ['tausend', 'likes', 'dauern', 'Schwule', 'Schüler', 'enttarnen', 'bedanken'],
#  ['ntv',
#   'tatsächlich',
#   'überraschen',
#   'Täter',
#   'Russland',
#   'Deutschland',
#   'finden',
#   'Qualität',
#   'deutsch',
#   'Medium',
#   'unterirdisch',
#   'Datendiebstahl'],
#  ['Spinne',
#   'Industrie',
#   'schießen',
#   'krank',
#   'Umweltdeppe',
#   'Wind',
#   'ruieni',
#   'Deutschland',
#   'fast',
#   'Merkel',
#   'schaffen',
#   'Rest',
#   'schaffen',
#   'Idiot'],
#  ['anchmal',
#   'Mensch',
#   'Tweet',
#   'einfach',
#   'still',
#   'arm',
#   'nehmen',
#   'manchmal',
#   'Mensch',
#   'Tweet',
#   'einfach',
#   'nett',
#   'sagen',
#   'fehlen',
#   'Mut',
#   'Furcht',
#   'Verletzung',
#   'beide',
#   'Seite',
#   'fressen',
#   'hinein'],
#  ['--',
#   'plädieren',
#   'monokausal',
#   'Korrelation',
#   'Emission',
#   'global',
#   'Klimawandel',
#   'unterstellen',
#   'global',
#   'Veränderung',
#   'Erde',
#   'schrecklich',
#   'klar',
#   'einbilden',
#   'kontrollieren'],
#  ['genau',
#   'Grund',
#   'Gebiet',
#   'antisemitisch',
#   'Polen',
#   'verschenken',
#   'europäisch',
#   'Judenstaat',
#   'errichten',
#   '--'],
#  ['Spiel', 'verlieren', 'Schiedsrichter', 'Fcsp'],
#  ['heissen',
#   'lang',
#   'lebend',
#   '....',
#   '\\"und',
#   'Tweet',
#   'amtssprach',
#   'arabisch',
#   'posten'],
#  ['Klimaaktiviste',
#   'plötzlich',
#   'religiös',
#   'fühlen',
#   'stören',
#   'Protest',
#   'Öfftl',
#   'Platz',
#   'Kirche',
#   'passieren',
#   'Lol'],
#  ['Mann', 'kaufen', 'mal', 'Nachfüllpackung', 'Textverständnis', '--'],
#  ['akk',
#   'kündigen',
#   'Kanzlerin',
#   'Merkel',
#   'CDU',
#   'widersprechen',
#   'zulässt.oh',
#   'Mutter',
#   'Tochter',
#   'Beziehung'],
#  ['grüne', 'weltfremd', 'klappen', 'Di', 'Fußnägel', 'annewill'],
#  ['sehen',
#   'Tempolimit',
#   'Freiheitsberaubung',
#   'Kollege',
#   'Feuerwehr',
#   'reichen',
#   'Erklärung'],
#  ['genannt', 'Person'],
#  ['süskram', 'kaufen', 'echt', 'sagen', 'Nichmehr', 'mein'],
#  ['Hmmmm', '--', 'fühlen', 'komisch', 'Punkt', '--', 'Fcsp'],
#  ["don't", 'Touch', 'the', 'Schaffner'],
#  ['Arbeitsminister',
#   'Hubertus',
#   'heil',
#   'SPD',
#   'Rente',
#   'sicher',
#   'solange',
#   'Rentner',
#   'genügend',
#   'Pfandflasche',
#   'Müll',
#   'finden.toll'],
#  ['hören',
#   'formelhaft',
#   'richtig',
#   'Kommunismus\\',
#   '100',
#   'Million',
#   'Leichenberg',
#   'wachsen',
#   'Venezuela',
#   'Problem',
#   'umsetzen',
#   'Problem',
#   'total',
#   'umsetzen',
#   'nolinke',
#   'Commiesraus'],
#  ['Deutschland',
#   'rätseln',
#   'Motiv',
#   'tatverdächtig',
#   'Wort',
#   'Islamismus',
#   'vermeiden',
#   'Pest'],
#  ['total',
#   'bescheueren',
#   'zufällig',
#   'Herzattacke',
#   'eventuell',
#   'todesangst',
#   'wildgeworden',
#   'Afghan',
#   'Kopf',
#   'herum',
#   'trampeln',
#   'echt',
#   'Arschlöcher',
#   'beschwichtigen',
#   'Redaktione',
#   'stürmen',
#   '100%ig'],
#  ['heuchlerisch', 'Marionett', 'schämen'],
#  ['Antizionismus', 'Form', 'Antisemitismus', 'Deal', 'with'],
#  ['Plärst', 'völkerrechtswidrig', 'Raum', 'dad', 'erklären', 'sagen', 'Isso'],
#  ['habn', 'ähnliches'],
#  ['Jakobiner',
#   'freuen',
#   'Gewalt',
#   'Zerstörung',
#   'Paris',
#   'offensichtlich',
#   'Demokratie',
#   'verabschieden'],
#  ['Merz',
#   'CDU',
#   'Hartz',
#   'beachtenswert',
#   'Leistung',
#   'unser',
#   'Sozialstaat',
#   'gut',
#   'Grund',
#   'Kriegzeite',
#   'Tafel',
#   'Suppenküche',
#   'Deutschland',
#   'Welkrieg',
#   'gab.hung',
#   'Deutschland',
#   'in.toll'],
#  ['Julian',
#   'Re****lt',
#   'tot',
#   'deutsch',
#   'Kofferraum',
#   'soeben',
#   'dunkl',
#   'dümem',
#   'arm',
#   'hoffnungslos'],
#  ['positiv', 'Beispiel', 'nennen', 'Mmmhh'],
#  ['selber', 'rausfinden', 'pah'],
#  ['aha', 'Zwergpudel', 'Schönschön'],
#  ['enschenrechte',
#   'Unterschied',
#   'gleich',
#   'Lohn',
#   'gleich',
#   'Arbeit',
#   'Satz',
#   'lachen',
#   'SPD',
#   'CDU',
#   'CSU',
#   'grün',
#   'FDP',
#   'Politiker'],
#  ['Prüfung', 'Haus', '2017', 'hansastrasse'],
#  ['einfach', 'herrlich', 'Rad', 'Punkt'],
#  ['Rechtsstaat',
#   'islamisch',
#   'Frauen-und',
#   'kinderschänd',
#   'Bewährung',
#   'frei',
#   'lässt',
#   'Nazi',
#   'abstempeln',
#   'verurteilen',
#   'korrupt',
#   'Asylpolitik',
#   'Islamisierung',
#   'Europa',
#   'stellen'],
#  ['Problem',
#   'Merkelsiedler',
#   '-parallelgesellschaften',
#   '-kriminelle',
#   'Familienclan',
#   '-unterdurchschnittliche',
#   'bildungserfolge',
#   '-überdurchschnittliche',
#   'transferleistungsbezüge',
#   '-antisemitismus',
#   '-islamismus',
#   '-frauendiskriminierung',
#   '-polygamie',
#   '-zwangsheirat',
#   '-kinderehen',
#   '-integrationsunwille'],
#  ['Nazi', 'Keule', 'brauchen', 'Erika', 'Schrank', '....'],
#  ['Vorschlag',
#   'Aufhebung',
#   'christlich',
#   '\\""feiertage\\"(6',
#   'gesetzlich',
#   'Urlaubsanspruch',
#   'addieren',
#   'Arbeitnehmer',
#   'wünschen',
#   'Urlaub',
#   'nehmen.neu',
#   'zusätzlich',
#   '1mai',
#   'Mai',
#   'März',
#   'November'],
#  ['Headline',
#   '2020',
#   'trotz',
#   'Ruhestand',
#   'Seehofer',
#   'drohen',
#   'rücktritt\\'],
#  ['Glaub', 'eher', 'Weirde', 'Paralleluniversum'],
#  ['Aue', 'Fcsp'],
#  ['berühmt',
#   'Putzfrau',
#   'Deutschlands',
#   'treten',
#   'SPD',
#   'linke-bewegung',
#   'aufstehen',
#   'einsetzen'],
#  ['hören', '.....'],
#  ['guck', 'Thread', 'Video', 'verlinken'],
#  ['spüren',
#   'linker',
#   'arm',
#   'kriechend',
#   'Kälte',
#   'ziehen',
#   'langsam',
#   'Schulter',
#   'hinein',
#   'Oberkörper'],
#  ['alt', 'Otto', 'ruhig'],
#  ['stehen',
#   'sowohl',
#   'flüchtlinge\\"al',
#   'Migrant',
#   'mittlerweile',
#   'Topf',
#   'schmissen',
#   'obwohl',
#   'völlig',
#   'egal',
#   'abgelehnt',
#   'asylforderer',
#   'illegal',
#   'Migrant',
#   'loswerden'],
#  ['dummerweise',
#   'neutralen\\"berichterstattung',
#   'Qualitätsmedien',
#   'z.b.',
#   'getötet',
#   'Palästinenser',
#   'meist',
#   'zahlen',
#   'Gesichter',
#   '--'],
#  ['jedesmal',
#   "wenn's",
#   'spannend',
#   'Streamprobleme',
#   '--',
#   "wenn's",
#   'jedesmal',
#   'Tor',
#   'leben',
#   'Fcsp',
#   'afmradio'],
#  ['weg', 'bleiben', 'Gentrifizierung'],
#  ['ernennen', 'mal', 'Präsident', 'Venezuela'],
#  ['Kapitalist',
#   'Klassenkampf',
#   'führen',
#   'Frage',
#   'kapitalisten',
#   'üben',
#   'Kapitalist',
#   'Klassenherrschaft',
#   'führen',
#   'institutionell',
#   'Klassenkampf',
#   'Kapitalist',
#   'einfach',
#   'Argument'],
#  ['unversöhnlich',
#   'riss',
#   'Deutschland',
#   '-vollhonks',
#   'Venezuela',
#   '2.0',
#   'anstreben'],
#  ['deutschstämmige', 'deutsch', 'deutsch', 'Staatsangehörigkeit'],
#  ['Nazi',
#   'stehen',
#   'träumen',
#   'Szene',
#   'Herr',
#   'Ringe',
#   'Geisterarmee',
#   '--',
#   'afdwegfegen'],
#  ['grün',
#   'Logik',
#   'dogmatisch',
#   'Kulturmarxismus',
#   'Idiot',
#   'kalt',
#   'Winter',
#   'Klimawandel',
#   'Schnee',
#   'Winter',
#   'Klimawandel',
#   'mild',
#   'Winter',
#   'Klimawandel',
#   'heiß',
#   'Sommer',
#   'Klimawandel',
#   'trocken',
#   'Sommer',
#   'Klimawandel',
#   'nass',
#   'Sommer',
#   'Klimawandel',
#   'Dummheit',
#   'Name'],
#  ['Klimaschützer', 'völkisch', 'Nest', 'legen'],
#  ['Buch',
#   'schreiben',
#   'verfilmen',
#   'Manta',
#   'namens',
#   'Manni',
#   'Hauptrolle',
#   'Fahrrad',
#   'Fisch'],
#  ['Markuslanz',
#   'peinlich',
#   'Dauerwerbesendung',
#   'bücher',
#   'müssten',
#   'unten',
#   'einblenden',
#   'zdf'],
#  ['geilste', 'Umfrage', 'Tag', 'Folge'],
#  ['Schröder', 'Grund'],
#  ['persönlich', 'brauchen', 'Atombombe', 'einkaufen', 'Herr'],
#  ['Erdogan',
#   'fatal',
#   'Fehler',
#   'Moschee',
#   'unzählig',
#   'Radikalisierungshäuser',
#   'erlauben',
#   'Erdogannotwelcom'],
#  ['guten-morgen-kackscheiss', 'muten', 'Aggression', 'beginnen'],
#  ['16-jährig',
#   'anfühlen',
#   'arm',
#   'schlimmste',
#   'Mutti',
#   'Tafel',
#   'Suppenküche',
#   'stehen',
#   'Angst',
#   'Schüler',
#   'sehen',
#   'Essen',
#   'betteln',
#   'muss.weil',
#   'SPD',
#   'grün',
#   'CDU',
#   'CSU',
#   'Regelsatz',
#   'willkürlich',
#   'klein',
#   'rechnen'],
#  ['amüsieren',
#   'diverser',
#   'windows-spiele',
#   'Linux',
#   'Lutris',
#   'Wine',
#   'mittlerweile',
#   'laufen',
#   'Window',
#   'einigermaßen',
#   'beeindrucken',
#   'System',
#   'Rock',
#   'solid'],
#  ['dienen',
#   'weder',
#   'imaginiert',
#   'volk\\"oder',
#   'obwohl',
#   'Kapitalismus',
#   'Wunschvorstellungen',
#   'linker',
#   'Schwäche',
#   'schreiben',
#   'würdest',
#   'personifiziert',
#   'Schwäche',
#   'schwach',
#   'Mensch',
#   'verurteilen'],
#  ['drücken', 'klar', 'verpiss', 'Mention'],
#  ['Glamour', 'Gala', 'Glitzer', 'Fcsp'],
#  ['glauben', 'angehusten', 'bitte', 'lassn', 'nächster', 'Mal'],
#  ['gehen',
#   'bestimmen',
#   'Zirkus',
#   'mal',
#   'Kind',
#   'Zirkus',
#   'schaffen',
#   'weltweit',
#   'Zirkuse',
#   'Tier',
#   'Akrobat',
#   'etc.',
#   '--',
#   'Tier',
#   'Wille',
#   'brechen',
#   'Reife',
#   'springen'],
#  ['Meldemuschi', 'machn', 'anderer', '--'],
#  ['betrachten',
#   'knapp',
#   'islamstaaen',
#   'Verfasst',
#   'Religionsfreiheit',
#   'gelten',
#   'sexuell',
#   'abweichend',
#   'behandeln',
#   'Stellung',
#   'Frau',
#   'betrachten',
#   'jung',
#   'Geschichte',
#   'Libanon',
#   'Umwälzung',
#   'muslimisch',
#   'Zuwanderung',
#   'erwarten',
#   'positiv'],
#  ['Einführung',
#   'Frauenwahlrecht',
#   'fesch',
#   'Adolf',
#   'Hitler',
#   'Eroberer',
#   'Frauenherze',
#   'trendy',
#   'Bärtche',
#   'Reichskanzler',
#   'wählen',
#   '100jahrefrauenwahlrecht'],
#  ['SPD',
#   'uner',
#   'Hartz',
#   'Sanktionsmöglichkeiten',
#   'Sorge',
#   'Mensch',
#   'Job',
#   'annehmen',
#   'überleben',
#   'Friss',
#   'stirben',
#   'zumindest',
#   'Arbeitgeber',
#   'lohnend',
#   'lohn',
#   'bringen',
#   'profit.toll',
#   'SPD'],
#  ['Andeutung',
#   'Richtung',
#   'hören',
#   'fragen',
#   'Wahlhelfer',
#   'melden',
#   'kriegen',
#   'Ausflücht',
#   'hören',
#   'Wahlhelfer',
#   'danken'],
#  ['Herkunft',
#   'Täter',
#   'fahren',
#   'Staatsmedie',
#   'gewohnt',
#   'Schuldkampagne',
#   'deutsche',
#   'ähnlich',
#   'beobachten',
#   'Täter',
#   'arabisch',
#   'afrikanisch',
#   'Herkunft',
#   'Bottrop'],
#  ['gehören',
#   'wissens',
#   'offiziell',
#   'Parteihaltung',
#   'Antisemit',
#   'Partei',
#   'schauen',
#   'mal',
#   'linker',
#   'grüne',
#   'SPD',
#   'genau',
#   'fündig'],
#  ['Fakt', 'findesn', 'Artikel'],
#  ['sale', 'mancgmal', 'nen', '10er', 'gönnen', 'link'],
#  ['2018',
#   '200',
#   'Karl',
#   'Marx',
#   '100',
#   'Novemberrevolution',
#   'Lyzi',
#   'Welt',
#   'zufall',
#   'glauben'],
#  ['laufen', 'schwierig', 'denken'],
#  ['CDU',
#   'Geheimplan',
#   '2019',
#   'SPD',
#   'Groko',
#   'Verlässt.dann',
#   'grün',
#   'FDP',
#   'Koalitionsgespräch',
#   'eingehen',
#   'Merkel',
#   'Mini',
#   'Merkel',
#   'akk',
#   'Kanzlerin',
#   'werden.der',
#   'Plan',
#   'geheim',
#   'öffentlich',
#   'stehen',
#   'Zeitung'],
#  ['Woke', 'gleichzeitig', 'drohen', 'flex'],
#  ['merken',
#   'manipulieren',
#   'Nazihorde',
#   'Mensch',
#   'Angst',
#   'sicher',
#   'Zukunft',
#   'Situation',
#   'unaufhaltbar',
#   'Enkel',
#   'erklären',
#   'wehren'],
#  ['lach',
#   'schlapp',
#   'verbotszonen',
#   'muslimisch',
#   'Mann',
#   'Feuerwerk',
#   'zünden',
#   'Polizei',
#   'gesengt',
#   'Kopf',
#   'weite',
#   'suchen',
#   'Anschluss',
#   'friedlich',
# ...
#   'Realitätsverweigerer',
#   'regelmäßig',
#   'Problem',
#   'solange',
#   'vermeintlich',
#   'Richtigen\\"erwischt',
#   'tolerierbar',
#   'Name',
#   'Demokratie',
#   'widern',
#   'unsagbar'],
#  ['krank',
#   'dumm',
#   'linker',
#   'Jugend',
#   'völlig',
#   'verblöden',
#   'fern',
#   'Realität',
#   'krank',
#   '--',
#   'krank',
#   'Hirn',
#   'Hirn',
#   'vorhanden'],
#  ['grau', 'Himmel', 'wohnen', 'passen', 'beschissen', 'Lage'],
#  ['liegen',
#   'all',
#   'falsch',
#   'deutsch',
#   'Revolution',
#   'absagen',
#   'betreten',
#   'Rasen',
#   'vor',
#   'Regierungsgebäude',
#   'verbieten',
#   'begnügen',
#   'sowieso',
#   'zebrastreifen',
#   'nächster',
#   'Lkw',
#   'kurz',
#   'Lunte',
#   'überfahren'],
#  ['hoffentlich', 'wurschen'],
#  ['grün',
#   'Dummgeschwätz',
#   'Maybritillner',
#   'sehen',
#   'Habeck',
#   'oll',
#   'Baerbock',
#   'verseucht',
#   'öffentlich',
#   'Fernsehen'],
#  ['Fanta',
#   'gestern',
#   'unbesiegbar',
#   'wirken',
#   'Schreit',
#   'groß',
#   'abend',
#   'normal',
#   'Leitungswasser',
#   'Bügeleisen'],
#  ['wichig',
#   'Gewalt',
#   'fetisch',
#   'verkommen',
#   'erinnern',
#   'rot',
#   'Armee',
#   'Rest',
#   'alliierter',
#   'Gewalt',
#   'speziell',
#   'Fall',
#   'sogar',
#   'zwingend',
#   '....'],
#  ['Familie', 'Nachzug', 'grüne', 'Syrien', 'ziehen', 'vermissen'],
#  ['Realität',
#   'Haifa',
#   'Palästinenser',
#   'Fassbombe',
#   'haus',
#   'Hafen',
#   'treiben',
#   'Mörserfeuer',
#   'nehmen',
#   'freiwillig',
#   'abreise\\"zu',
#   'beschleunigen',
#   'gewaltsam',
#   'Schiff',
#   'Meer',
#   'treiben',
#   'ertranken'],
#  ['betreten',
#   'obe',
#   'sozialistisch',
#   'Gang',
#   '--',
#   'Dfbpokalistunsscheißegal',
#   'Fcsp'],
#  ['Besserung', 'siehen', 'Shiras', 'Eltern', 'stark'],
#  ['scheißangst', 'uswahl16'],
#  ['stellen',
#   'Asyl',
#   'Antrag',
#   'pissen',
#   'lachen',
#   'blöd',
#   'Michel',
#   'Buchse',
#   '....',
#   'herrlich'],
#  ['gewinnen', 'Fcsp'],
#  ['nit', 'zeigen', 'Chat', 'ottos'],
#  ['finden', 'falls', 'suchen', 'sein-', 'Zimmer'],
#  ['offensichtlich',
#   'Fan',
#   'diverser',
#   'rechtsradikal',
#   'Feed',
#   'bände',
#   'sprechen',
#   'Bruahahahahahaha',
#   'Faschist',
#   'sehen',
#   'schau',
#   'einfach',
#   'Spiegel'],
#  ['vollkommen', 'postmodern', 'Drönung', 'abbekommen'],
#  ['viertelwahrtheiten\\"poste',
#   'widerlegen',
#   'einfach',
#   'werfen',
#   'Beschimpfung',
#   'einfach',
#   'Lage'],
#  ['sprechen',
#   'europäisch',
#   'Jude',
#   'Jahrhundert',
#   'Verfolgung',
#   'sprechen',
#   'übertreiben',
#   'phasen',
#   'Antijudaismus',
#   'überwiegen',
#   'krisenzeien',
#   'Sündenbock',
#   'brauchen',
#   'meist',
#   'leben',
#   'nebeneinander'],
#  ['Antifaschismus',
#   'ziemlich',
#   'Antifaschist',
#   'willkommen',
#   'hinterher',
#   'streiten',
#   'hoffentlich',
#   'fruchtbar',
#   'streiten'],
#  ['Text',
#   'lesen',
#   'anhand',
#   'arbeiten\\"analysier',
#   'bestimmt',
#   'Prozentsatz',
#   'fakt',
#   'falsch',
#   'Grundstein',
#   'praktisch',
#   'Text',
#   'ähnlich',
#   'gleich',
#   'Fehler',
#   'aufweisen'],
#  ['Befreiung', 'Lohnarbeit', 'feiern', 'back', 'tarte'],
#  ['schreiben', 'Seele', 'Leib', 'reagieren', 'Empfänger', 'weißen', 'lesen'],
#  ['Erfinder',
#   'politisch',
#   'Zionismus',
#   'Urvater',
#   'Kolonie',
#   'Jabotinsky',
#   'wiederum',
#   'revisionistisch',
#   'zionismus',
#   'erfinden',
#   'heutig',
#   'Politik',
#   'Israel',
#   'fußen'],
#  ['arbeiten', 'klären'],
#  ['Trotzkist', 'schlecht', 'Autor', 'objektiv', 'reaktionär'],
#  ['sandhausen', 'leiden', '--', 'fcsp'],
#  ['klar',
#   'stellen',
#   'white-washing',
#   'betreiben',
#   'Unterstützung',
#   'Kurde',
#   'entente-mächte',
#   'versprechen',
#   'belohnen',
#   'etlich',
#   'leid',
#   'Folge',
#   'ersparen',
#   'bleiben',
#   'just',
#   'cents'],
#  ['arm',
#   'Gewalt',
#   'Krieg',
#   'Terror',
#   'fliehend',
#   'afghanisch',
#   'Flüchtling',
#   'psychisch',
#   'hart',
#   'Bewährungsstrafe',
#   'fertig'],
#  ['Coca',
#   'Cola',
#   'hiermit',
#   'raus',
#   'gutmensch',
#   'nazi',
#   'Trittbrett',
#   'aufspringen',
#   'bekommen',
#   'quittung'],
#  ['ermordet',
#   'Baby',
#   'Beerdigung',
#   'Name',
#   'Amiad',
#   'Yisrael',
#   'geben',
#   'Baruch',
#   'Dayan',
#   "Ha'emet"],
#  ['schön',
#   'Schluss',
#   'fast',
#   'pointiert',
#   'wirken',
#   'versuchen',
#   'antideutsch',
#   'Begriff',
#   'postmodern',
#   'Kontext',
#   'umzudefinieren',
#   'Deutschland'],
#  ['Vapen', 'rauchen', 'Menner'],
#  ['Vorwurf\\"der',
#   'Aussage',
#   'speisen',
#   'falsch',
#   'Problem',
#   'bleiben',
#   'Aussage',
#   'pauschal',
#   'Heuteshow',
#   'reagieren',
#   'Haltung',
#   'deutlich'],
#  ['Rolle', 'spielen'],
#  ['unglaublich',
#   'Hartz-iv-empfänger',
#   'lehnen',
#   'Euro',
#   'Job',
#   'stellen',
#   'unverschämt',
#   'Forderung',
#   'Arbeit',
#   'Vollzeit',
#   'Job',
#   'lohn',
#   'leben',
#   'kann.wo',
#   'leben',
#   'Mensch',
#   'verlangen',
#   'SPD',
#   'Hartz',
#   'System'],
#  ['lächerlich', '--', 'fcsp'],
#  ['Brexit',
#   'Times',
#   'befinden',
#   'Merkel',
#   'CDU',
#   'may',
#   'demütigen',
#   'may',
#   'deutsch',
#   'Volk'],
#  ['obdachlose',
#   'Geld',
#   'verdienen',
#   'kriminell',
#   'Islam',
#   '/afrik',
#   'Migrant',
#   'asylanten',
#   'Flüchtling',
#   'steuergeldern',
#   'alimentieren',
#   'füllen',
#   'Kasse',
#   'korrupt',
#   'Asylindustrie',
#   'Caritas',
#   'Kirche',
#   'Etc.',
#   'etc.'],
#  ['pleite', 'würgen', 'zugucken', 'Ibes'],
#  ['Tradition', 'wahrscheinlich', 'richtig', 'Duelle'],
#  ['Zweifel'],
#  ['hab',
#   'Menge',
#   'Videos',
#   'Thema',
#   'Nahost',
#   '--',
#   'mal',
#   'Liste',
#   'zusammenstellen'],
#  ['bisschen', 'Antiintellektualismus', 'stehen', 'Gesicht'],
#  ['Tatort', 'mal'],
#  ['Breaking',
#   'news++',
#   'Annegret',
#   'kramp-karrenbauer',
#   'beliebt',
#   'Politikerin',
#   'Welt',
#   'Pferd',
#   'wiehern',
#   'Peter',
#   'Altmaier',
#   'abnehmen',
#   'Telefonhörer',
#   'Flüchtling',
#   'bip',
#   'verantwortlich',
#   'deutsch',
#   'arbeiten',
#   'schaffen'],
#  ['echt',
#   'Naivlinge',
#   'Thread',
#   'unfassbar',
#   'blind',
#   'taub',
#   'schwachsinnig',
#   'unfassbar'],
#  ['Fisch', 'Fahrrad'],
#  ['gleich',
#   'Problematik',
#   'hab',
#   'gestern',
#   'Bett',
#   'verabschieden',
#   'Kreis',
#   'drehen',
#   'glauben',
#   'nichtmehr',
#   'durchbrechen',
#   'mach',
#   'beenden',
#   'Thema',
#   'rum'],
#  ['naja',
#   'hoffen',
#   'genügend',
#   'Aufklärung',
#   'lächerlichster',
#   'Propaganda',
#   'betreiben',
#   'incl.',
#   'verblendet',
#   'Followerschaft',
#   'vmtl',
#   'spät'],
#  ['zweimal',
#   'gleich',
#   'Angst',
#   'falsche',
#   'zweimal',
#   'grenzenlos',
#   'Stress',
#   'Eingewöhnungsphase'],
#  ['Island'],
#  ['setzen',
#   'Krieg',
#   'Gegenpartei',
#   'voraus',
#   'zumindest',
#   'ansatzweise',
#   'wehren',
#   'sehe',
#   'Saudiarabien',
#   'Vernichtungstrip',
#   'verbündeter',
#   'schuldig'],
#  ['nochmal',
#   'einschalten',
#   'vermeindlich',
#   'Wissenschaft',
#   'wiederlegt',
#   'ergebnissen',
#   'festhalten',
#   'ausblenden',
#   'Fundament',
#   'weit',
#   'These',
#   'nutzen',
#   'weiterhin',
#   'diskussionsfähig',
#   'bleiben',
#   'eindeutig',
#   'Ideologie'],
#  ['Fluchttaxi',
#   'Fahrer',
#   'finden',
#   'gehen',
#   'erstmal',
#   'Netzwerk',
#   'geiselnahmen'],
#  ['sturmhaube', 'Profilbild', 'autonom', 'Jaja'],
#  ['schwer',
#   'Fehler',
#   'Moschee',
#   'Köln',
#   'bauen',
#   'Platz',
#   'sozialwohnung',
#   'Park',
#   'Döner',
#   'buden',
#   'Kino',
#   'wissen',
#   'bauen',
#   'Hartaberfair',
#   'Erdogannotwelcom'],
#  ['fertig'],
#  ['beiseite',
#   'legen',
#   'können',
#   'schleppen',
#   'Geld',
#   'Bank',
#   'verbrennen',
#   'Negativzinse',
#   'allerkleinste',
#   'Risiko',
#   'eingehen'],
#  ['deutsch',
#   'Synchro',
#   'einfach',
#   'perfekt',
#   'restlich',
#   'fallen',
#   'einzeln',
#   'sätze',
#   'Statist',
#   'Stimme',
#   'passen',
#   'unglaublich',
#   'Katara',
#   'Tophs',
#   'Sprecher',
#   'bae',
#   'Zuko',
#   'klingen',
#   'Vater',
#   'Narbe',
#   'auchnoch',
#   'kastrieren'],
#  ['Bäum',
#   'mal',
#   "'n",
#   'Wald',
#   'spazieren',
#   'gehen',
#   "so'n",
#   'Baum',
#   'greifen',
#   'glatt',
#   "'n",
#   'zapfen',
#   'mal',
#   'Leben',
#   'kommen'],
#  ['stümmt', "war's", '--', 'Asche', 'nehmen', 'Zahnpasta'],
#  ['anti-israel-fetisch', 'identity', 'Politics'],
#  ['lustig',
#   'Mensch',
#   'Eignung',
#   'absprechen',
#   '-----------------------------------------',
#   'Paradebeispiel',
#   'Parasit',
#   'rot',
#   'Gewand',
#   'Hohn',
#   'arbeiter\\"mit',
#   'manikürt',
#   'Fingerchen'],
#  ['reden', 'SPD'],
#  ['lieblings-berufslügner', 'treiben', 'Twitter', 'rum', 'Pummeliger', '--'],
#  ['irre',
#   'one',
#   'world\\"libtards',
#   'USA',
#   'durchgeknallt',
#   'Linkoid',
#   'Europa',
#   'borders',
#   'nations\\',
#   'Idiotie',
#   'wohlig',
#   'Geborgenheit',
#   'Oase',
#   'Nation',
#   'weiß',
#   'alt',
#   'männer\\',
#   'fordern',
#   'grausam',
#   'Wüste',
#   'Welt',
#   'bewahren'],
#  ['echt', 'frusten', '--', 'sorry', 'einfach', 'Mist', 'Fcsp'],
#  ['Ergebnis',
#   'Fem',
#   'diversity',
#   'Regenbogen',
#   'refugees',
#   'welcome',
#   'linker',
#   'ect',
#   'degenerieren',
#   'harmlos',
#   'eierlos',
#   'verblendet',
#   'schwachsinnig',
#   'weibisch',
#   'wohlstands-',
#   'Witzfiguren',
#   'bilden',
#   'Faust',
#   'Kapselzerrung',
#   'zuziehen',
#   'krank',
#   'krank'],
#  ['Stunde', 'wochenarbeitszeit', 'eher', 'bringe', '--'],
#  ['nahl',
#   'SPD',
#   'letzter',
#   'halb',
#   'passieren',
#   'absolut',
#   'hinnehmbar',
#   'akzeptieren',
#   'Zukunft',
#   'Satz',
#   'sagen',
#   'Groko'],
#  ['Luis', 'xvi', 'erstmal', 'kokade', 'tragen'],
#  ['16h',
#   'Paulsplatz',
#   'Römer',
#   'Frankfurt',
#   'Protestaktion',
#   'Zuverlässigkeitsüberprüfung',
#   'Gesinnungsüberprüfung',
#   'Staatsschutz'],
#  ['schockverliebt', 'dein', 'Mann', 'Ehrenmann', 'alt', 'aufrecht', 'Garde'],
#  ['real', 'Hetzgagd', 'schutzsuchender', 'Amberg', 'Einheimische'],
#  ['Gibs',
#   'Single',
#   'Schreib',
#   'sexspielchen',
#   'keller\\"hittet',
#   'nurnoch',
#   'Hose'],
#  ['meinst', '--', 'Begriff', 'Terror', 'naja', '....', 'machs'],
#  ['mal',
#   'Verantwortung',
#   'tragen',
#   'Konstrukt',
#   'Brd',
#   'Alibi',
#   'Demokratie',
#   '....'],
#  ['Hass', '--', '--', 'all', 'cops', 'are', 'Bastard', '--', 'Acab'],
#  ['kommen', 'Teppich', 'treffen', 'Regionalliga'],
#  ['exakt',
#   'global',
#   'Elite',
#   'sehen',
#   'saudi-arabien',
#   'Königsfamilie',
#   'rollenmodell',
#   'perfekt',
#   'Feudalsystem',
#   'Volkswiderstand',
#   'bauen',
#   'Europa',
#   'massiv',
#   'Sinn',
#   'Ansiedlung',
#   'muslimisch',
#   'Araber',
#   'Afrikaner',
#   'Stil',
#   'Islamisierung',
#   'Senkung'],
#  ['Respekt', 'Opfer', '--', 'menschenfeind', 'Fckafd'],
#  ['kennen',
#   'sicherlich',
#   'paar',
#   'Dutzend',
#   'ashkenazim',
#   'optisch',
#   'nicht-europäisch',
#   'sehen',
#   '--'],
#  ['Twittergroßmaul', 'eingeloggt'],
#  ['uff', 'Tokenismus', 'Person', 'sprechen'],
#  ['Punkt',
#   'Glück',
#   'reißen',
#   'unbeteiligte',
#   'fahren',
#   'beruflich',
#   'erleben',
#   'Leute',
#   'Auto',
#   'greifen',
#   '160',
#   'km/h',
#   'schrumpfen',
#   'Reaktionsgeschwindigkeit',
#   'Prozentual',
#   'Aufprallenergie'],
#  ['ca.',
#   'Woche',
#   'intensiv',
#   'Räumung',
#   'letzter',
#   'sog.',
#   'aktivisten',
#   'Straftäter',
#   'merken',
#   'verlieren',
#   'glauben',
#   '100',
#   'eur',
#   'infiziert',
#   'Randale',
#   'jüngern',
#   'nochmal',
#   'Hambacherforst',
#   'sehen',
#   'lassen',
#   'hambifällt'],
#  ['Frage', 'berechtigen'],
#  ['enschenrechte',
#   'Sklaverei',
#   'Leibeigenschaft',
#   'halten',
#   'Sklaverei',
#   'Sklavenhandel',
#   'Form',
#   'Verboten.daran',
#   'halten',
#   'SPD',
#   'Hartz',
#   'Sytem',
#   'Hungerlohn',
#   'arbeiten',
#   'Sanktion',
#   'Sklaverei',
#   'zwingen'],
#  ['blöderweise',
#   'Nazifamilie',
#   'Hand',
#   'einfach',
#   'Nachbar',
#   'aufknüpfen',
#   'weihnachten'],
#  ['ziemlich',
#   'Machwerke',
#   'einziger',
#   'zumindest',
#   'tendenziös',
#   'Tatsache',
#   'verdrehen',
#   'fangen',
#   'unanbhängig\\"an',
#   'zionisten',
#   'Propaganda',
#   'Gehalt',
#   'bezahlen',
#   'lässt',
#   'unabhängig'],
#  ['zionistisch',
#   'Stahlbaron',
#   'gekauft',
#   'Lügner',
#   'verleumd',
#   'wach',
#   '....',
#   'Nullnummer',
#   'eigentlich',
#   'überstunden',
#   'ordentlich',
#   'bezahlen',
#   'hetzen',
#   'all-inclusive'],
#  ['Wurst', 'schmausen'],
#  ['Edit',
#   'fragen',
#   'Frauenhasser',
#   'behanden',
#   'richtig',
#   'Frau',
#   'Gentleman',
#   'tragen',
#   'Frau',
#   'Händen',
#   'hirngefickt',
#   'Mann',
#   'hassend',
#   'Fem',
#   'gestalten',
#   'verschieden',
#   'Geschlechter',
#   'Arsch',
#   'vorbei'],
#  ['interessiert',
#   'Wohnungsdurchsuchung',
#   'Terrorist',
#   'europaparlament',
#   'erhöht',
#   'Sicherheitsstuf'],
#  ['einst',
#   'mehrere',
#   'mörder',
#   'Terrorbande',
#   'zusammengewürfelt',
#   'Haufen',
#   'Feiglinge',
#   'hightech-waffen',
#   'steinewerfern',
#   'verstecken',
#   'Verteidigung',
#   'nennen',
#   'Terrororganisation',
#   'richtig',
#   'Name',
#   'Israeli',
#   'Terror',
#   'forces'],
#  ['nebenbei',
#   'rasseln',
#   '3-d-test',
#   'Dämonisierung',
#   'Palästinenser',
#   'Terrorist',
#   'Delegitimierung',
#   'absprechen',
#   'Statu',
#   'einheimisch',
#   'doppelt',
#   'Standard',
#   'anderer',
#   'verhalten',
#   'erwarten',
#   'anderer',
#   'Opfer',
#   'siedlerkolonial',
#   'Regime'],
#  ['Tor', 'geil', '--', 'giggel', 'Fcsp'],
#  ['wundern',
#   'evtl.',
#   'ankommen',
#   'meinen',
#   'wesentlich',
#   'warm',
#   'denken',
#   '--'],
#  ['Jetz', 'Layer'],
#  ['menschlich', 'Abschaum', 'Nazi', 'Hysterie', 'Daseinsberechtigung'],
#  ['gehen', 'pennen', 'völlig', 'normal', 'Existenz'],
#  ['Unterschied',
#   'staatlich',
#   'Schlägertruppe',
#   'santifa',
#   'Bundesamt',
#   'Verfassungsschutz',
#   'scheinbar',
#   'Kopf',
#   'arm'],
#  ['Punkt', 'stimmen'],
#  ['alt', 'alt'],
#  ['gemeinsam', 'fliegen', 'Okok'],
#  ['erwarten',
#   'Schluchtis',
#   '--',
#   'raus',
#   'Generation',
#   'Eltern',
#   'geschwister',
#   '--'],
#  ['offiziell', 'beeindruckt', 'Fcsp'],
#  ['genau', 'bedeuten', 'machen'],
#  ['habn', 'erotisch', 'Gedanke\\"gelese', 'stutzig'],
#  ['Studie',
#   'bertelsmann-stiftung',
#   'Kindergeld',
#   'Erhöhung',
#   'helfen',
#   'Kinderarmut',
#   'Kindergeld',
#   'arm',
#   'kind',
#   'SPD',
#   'Hartz',
#   'Regelsatz',
#   'abziehen',
#   'wird.kindergeld',
#   'Einkommen',
#   'anrechnen',
#   'SPD',
#   'echt',
#   'asozioal',
#   'Partei'],
#  ['mal',
#   'lehnen',
#   'Kernkraft',
#   'contra',
#   'Spaltung',
#   'pro',
#   'Fusion',
#   'Grund',
#   'nah',
#   'erläutern',
#   'Grund',
#   'Partei',
#   'Programm',
#   '100',
#   'entsprechen',
#   'Haltung',
#   'Vision',
#   'wichtig'],
#  ['uninformieren',
#   'mehrere',
#   'Schraube',
#   'locker',
#   'Spaß',
#   'lesen',
#   'nächster',
#   'wahlergebnisse',
#   'afdwirkt'],
#  ['Zahl',
#   'Waffenscheine',
#   'Deutschland',
#   'laut',
#   'Medienbericht',
#   'steigen',
#   'toll',
#   'sehen',
#   'Kalaschnikow',
#   'Straße'],
#  ['enschen',
#   'ebay-kleinanzeigen',
#   'verticken',
#   'wohnen',
#   'dickicht',
#   'Gartenlaube',
#   'oberer',
#   'Stock',
#   'Altbau',
#   'Hinterhaus',
#   'Issso'],
#  ['Hack', 'Goethe', 'Lichtenberg', 'Arno', 'Schmidt'],
#  ['Stalinismus',
#   'Nazi',
#   'abschaffen',
#   'liberale',
#   'fordern',
#   'Diskussionsrund',
#   'Nice',
#   'Faschismus',
#   'hervorbringend',
#   'bürgerlich',
#   'Demokratie',
#   'retten',
#   'natzen',
#   'Leute'],
#  ['wieviele',
#   'islamisch',
#   'Terrortempel',
#   'Ausbildungsstätt',
#   'islamisch',
#   'Halbmondritter',
#   'bauen',
#   'linker',
#   'deutsch',
#   'islamisch',
#   'Bundesregierung',
#   'korantreu',
#   'Moslems',
#   'Hamas',
#   'Schlüssel',
#   'Deutschland',
#   'überreichen',
#   'auf',
#   'gleich',
#   'raus'],
#  ['Nacht', 'Tweet', 'infos', 'Täter', 'verschwinden', 'unsichtbar'],
#  ['yotta', 'versuchen', 'heulen', 'pinkeln', 'klappen', 'Ibes'],
#  ['politiküsse',
#   'kapieren',
#   'Afd',
#   'nacheifern',
#   'werben',
#   'Wähler',
#   'bestätigen',
#   'Wähler',
#   'verlieren',
#   'stimmen',
#   'anstatt',
#   'gewinnen'],
#  ['dreie'],
#  ['Leude', 'Lust', 'Smeeesh'],
#  ['egal',
#   'Regierung',
#   '....',
#   'Staat',
#   'Nation',
#   'Kapital',
#   'Scheiße',
#   'Solidarität',
#   'betroffener',
#   'Rigaer',
#   '....'],
#  ['kennen', 'schön'],
#  ['Trichophobe',
#   'Kopfwindel',
#   'Begriff',
#   'prägen',
#   'Kampfbegriff',
#   '\\""islamophobie\\'],
#  ['Fußpilz', 'beliebt', 'Merkel', 'insofern', '--'],
#  ['Anche',
#   'Opfer',
#   'Breitscheidtplatz',
#   'enden',
#   'gesichtslos',
#   'blutig',
#   'Klumpe',
#   'Fleisch',
#   'zermalmt',
#   'Knoche',
#   'dna',
#   'identifizierbar'],
#  ['Wert', 'absolut', 'setzen', 'Kritik', 'tot', 'somit', 'Emanzipation', '--'],
#  ['genau',
#   'beweisen',
#   'euer',
#   'Job',
#   'Verleumden',
#   'Mensch',
#   'Einhaltung',
#   'Völkerrecht',
#   'Menschenrecht',
#   'einsetzen',
#   'allseits',
#   '--'],
#  ['nich', 'nen', 'Menschenschwanz', 'Hühnerkloake', 'Dreckshaufen'],
#  ['bereit', 'kür', 'Fcsp'],
#  ['dankbar', 'Twitter', 'Qualifilter', 'voll', 'Dröhnung', 'mitbekommen'],
#  ['gestalten', 'blockieren', 'Linksdeutsch', 'Nazi', 'gelten'],
#  ['Konstrukt',
#   'brd',
#   'Rosenthal',
#   'Plan',
#   'umgestalten',
#   'spielen',
#   'Bildung',
#   'Rolle',
#   '....'],
#  ...]

# %%
import fasttext
import fasttext.util
from gensim.models.fasttext import *
# ft = fasttext.load_model("/Users/jannis/cc.de.300.bin")
ft = load_facebook_model("/Users/jannis/cc.de.300.bin")

# %%
len(tweet_words)
# Out:
# 2273

# %%
# continue training pretrained model
ft.build_vocab(tweet_words, update=True)
ft.train(tweet_words, total_examples=len(tweet_words), epochs=10)
# Out:
# (98934, 214680)

# %%
ft.wv.most_similar(["Deutschland", "Merkel"], topn = 5)
# Out:
# [('Bundeskanzlerin', 0.9851183295249939),
#  ('Kanzlerin', 0.9834180474281311),
#  ('Merkel-Deutschland', 0.9822767376899719),
#  ('Merkel-Regierung', 0.9808183908462524),
#  ('Bundesregierung', 0.9793848991394043)]

# %%
ft.wv.most_similar(["Korruption", "Europa"], topn = 5)
# Out:
# [('Deutschland', 0.9799163341522217),
#  ('Globalisierung', 0.9747747778892517),
#  ('EU-Wirtschaft', 0.9738207459449768),
#  ('europäischen', 0.9736407995223999),
#  ('Wirtschaftsmächten', 0.9735116362571716)]

# %%
ft.wv.most_similar(["Polizei"], topn = 5)
# Out:
# [('Polizeit', 0.9683308005332947),
#  ('Bundespolizei', 0.9553856253623962),
#  ('Polizeidirektion', 0.9544669389724731),
#  ('Polizisten', 0.9539645314216614),
#  ('Verwaltungspolizei', 0.9527090787887573)]

# %%
# reduce dimensions
# fasttext.util.reduce_model(ft, 100)

# %%
# unique list of words
uni_tweet_words = list(ft.wv.key_to_index.keys())

# %%
# Remove tweets where there are no words in the fasttext model
def remove_nan_tweets(tweet_words, model):
    tweet_words_dict = {}
    for tweet in tweet_words:
        sum_occurr = 0
        for word in tweet:
            if word in model:
                sum_occurr +=1
        if sum_occurr > 0:
            tweet_words_dict[tweet_words.index(tweet)] = True

    return tweet_words_dict

tweet_words_dict = remove_nan_tweets(tweet_words, uni_tweet_words)
    
# subset data_pre and tweet_words, only tweets where at least one word is in the word2vec model
data_pre = data_pre.iloc[list(tweet_words_dict.keys()), :]
data_pre = data_pre.reset_index()
tweet_words = [tweet_words[i] for i in list(tweet_words_dict.keys())]

# %%
len(data_pre)
# Out:
# 2257

# %% [markdown]
# ## Classify new tweets

# %%
# calculate center of mass vector for list of words (used here for article as
# collection of words)
def get_com_vector(words : list) -> np.array:
    # list of words in the word2vec model
    words = [word for word in words if word in uni_tweet_words]
    # get the vectors
    vectors = np.array([ft.wv[word] for word in words])
    # return the sum of all vectors devided by the amount of words from words in the model
    vector = np.sum(vectors, axis=0)
    return vector / len(words)

# get vector for each tweet
tweet_vectors = []
for tweet in tweet_words:
    vec = get_com_vector(tweet)
    tweet_vectors.append(vec)

# %%
# function to preprocess and transform new tweets
def new_tweet_vector(tweet : str):
    prep_new = tweet
    doc_new = nlp(prep_new)

    words_new = [
                    word.lemma_ for word in doc_new
                    if (not word.is_stop) and (len(word)>2)
                 ]

    # calculate vector for new article
    new_tweet_v = get_com_vector(words_new)

    return new_tweet_v, words_new

# %%
# create tweet vectors of test tweets
new_tweet_v = []
words_new = []
for tweet in data_test.tweets_clean:
    new_tweet_v.append(new_tweet_vector(tweet)[0])
    words_new.append(new_tweet_vector(tweet)[1])
# Out:
# /var/folders/gz/m10sqzrs1zv7071q82xq75fh0000gn/T/ipykernel_63186/3232258470.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   return vector / len(words)

# %%
# Remove tweets where there are no words in the word2vec model  
tweet_words_dict = remove_nan_tweets(words_new, uni_tweet_words)   

# subset data_test and tweet_words, only tweets where at least one word is in the word2vec model
data_test = data_test.iloc[list(tweet_words_dict.keys()), :]
data_test = data_test.reset_index()
new_tweet_v = [new_tweet_v[i] for i in list(tweet_words_dict.keys())]

# %%
# Encode the classes
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
y_transformed = encoder.fit_transform(data_pre["granulareKlassifikation"])
encoder.classes_
# Out:
# array(['ABUSE', 'INSULT', 'OTHER', 'PROFANITY'], dtype=object)

# %%
# Train a Random Forest
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(tweet_vectors, y_transformed)
rfc_predictions = rfc.predict(new_tweet_v)
# rfc_human_readeable = encoder.inverse_transform(rfc_predictions)

# %%
# transform predictions to classes
encoder_dict = dict(enumerate(encoder.classes_.flatten(), 0))
rfc_predictions = [encoder_dict[x] for x in rfc_predictions]

# %%
# evaluate predictions
acc = 0
for i in range(len(rfc_predictions)):
    if rfc_predictions[i] == data_test["granulareKlassifikation"][i]:
        acc += 1
accuracy = acc / len(rfc_predictions)

# %%
accuracy
# Out:
# 0.9165562913907285

# %%
# classification report
from sklearn.metrics import classification_report
print(classification_report(data_test["granulareKlassifikation"], rfc_predictions))
# Out:
#               precision    recall  f1-score   support
#
#        ABUSE       1.00      0.80      0.89        86
#       INSULT       1.00      0.77      0.87       170
#        OTHER       0.88      1.00      0.94       472
#    PROFANITY       1.00      0.74      0.85        27
#
#     accuracy                           0.92       755
#    macro avg       0.97      0.83      0.89       755
# weighted avg       0.93      0.92      0.91       755

# %%
rfc_predictions[:10]
# Out:
# ['ABUSE',
#  'INSULT',
#  'INSULT',
#  'INSULT',
#  'OTHER',
#  'OTHER',
#  'INSULT',
#  'OTHER',
#  'OTHER',
#  'OTHER']

# %%
data_test["granulareKlassifikation"][:10]
# Out:
# 0     ABUSE
# 1    INSULT
# 2    INSULT
# 3    INSULT
# 4    INSULT
# 5    INSULT
# 6    INSULT
# 7     OTHER
# 8     OTHER
# 9     OTHER
# Name: granulareKlassifikation, dtype: object

# %%
# value counts of predictions
[cat_predictions.count(x) for x in ['ABUSE', 'PROFANITY','INSULT', 'OTHER']]

# %%
data_test["granulareKlassifikation"].value_counts()

# %%
data_test.head(10)
